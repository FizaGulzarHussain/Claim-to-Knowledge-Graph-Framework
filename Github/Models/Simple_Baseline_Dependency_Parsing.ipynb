# %% [markdown]
# # Politics

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import re
import pandas as pd
import bs4
import requests
import spacy
from spacy import displacy
nlp = spacy.load('en_core_web_sm')

from spacy.matcher import Matcher 
from spacy.tokens import Span 

import networkx as nx

import matplotlib.pyplot as plt
from tqdm import tqdm

pd.set_option('display.max_colwidth', 200)
# %matplotlib inline

# %%
candidate_sentences = pd.read_csv("/content/drive/MyDrive/Politics.csv")
candidate_sentences.shape
# Out:
# (2998, 3)

# %%
candidate_sentences.head()
# Out:
#                                                                  Titles  \
# 0  Service delivery sole criteria to compete for public office, says PM
# 1                                      Grand dialogue on polls proposed
# 2       Politicians advised to mend fences to prevent economic meltdown
# 3             Who cares about the economy in this political tug of war?
# 4       Jokes, racism: The many reactions to Humza Yousaf's appointment
#
#                                                                                                                                                                                                articleText  \
# 0  Prime Minister Shehbaz Sharif on Wednesday said politics in the country has been reduced to "meaningless rhetoric" and termed service delivery as the main criterion to compete for public office. \...
# 1  QUETTA:\n\nSenator Samina Mumtaz Zehri has said that as far as new elections are concerned in Pakistan, for the sake of the integrity and the interest of the country, all the stakeholders should h...
# 2  KARACHI:\n\nPakistan's economy has partially shut down and millions of people have lost jobs due to continuous political instability. The nation is destined to encounter hyperinflation with the do...
# 3  KARACHI:\n\nThe dollar rate is now a religious hymn, with everyone from rags to riches quoting it. A country’s currency is one of the key reflections of its economic strength or lack thereof. Chat...
# 4  Humza Yousaf made history after his appointment as the First Minister of Scotland --- being the first person of colour and the first Muslim to hold the coveted post. Of Pakistani descent, the new ...
#
#                         date_author
# 0        News Desk \nApril 19, 2023
# 1              APP \nApril 08, 2023
# 2  Salman Siddiqui \nApril 03, 2023
# 3       AAH Soomro \nApril 03, 2023
# 4      Social Desk \nMarch 30, 2023

# %%
doc = nlp("the drawdown process is governed by astm standard d823")

for tok in doc:
  print(tok.text, "...", tok.dep_)
# Out:
# the ... det
# drawdown ... amod
# process ... nsubjpass
# is ... auxpass
# governed ... ROOT
# by ... agent
# astm ... compound
# standard ... compound
# d823 ... pobj

# %%
def get_entities(sent):
  ## chunk 1
  ent1 = ""
  ent2 = ""

  prv_tok_dep = ""    # dependency tag of previous token in the sentence
  prv_tok_text = ""   # previous token in the sentence

  prefix = ""
  modifier = ""

  #############################################################
  
  for tok in nlp(sent):
    ## chunk 2
    # if token is a punctuation mark then move on to the next token
    if tok.dep_ != "punct":
      # check: token is a compound word or not
      if tok.dep_ == "compound":
        prefix = tok.text
        # if the previous word was also a 'compound' then add the current word to it
        if prv_tok_dep == "compound":
          prefix = prv_tok_text + " "+ tok.text
      
      # check: token is a modifier or not
      if tok.dep_.endswith("mod") == True:
        modifier = tok.text
        # if the previous word was also a 'compound' then add the current word to it
        if prv_tok_dep == "compound":
          modifier = prv_tok_text + " "+ tok.text
      
      ## chunk 3
      if tok.dep_.find("subj") == True:
        ent1 = modifier +" "+ prefix + " "+ tok.text
        prefix = ""
        modifier = ""
        prv_tok_dep = ""
        prv_tok_text = ""      

      ## chunk 4
      if tok.dep_.find("obj") == True:
        ent2 = modifier +" "+ prefix +" "+ tok.text
        
      ## chunk 5  
      # update variables
      prv_tok_dep = tok.dep_
      prv_tok_text = tok.text
  #############################################################

  return [ent1.strip(), ent2.strip()]

# %%
candidate_sentences.head()
# Out:
#                                                                  Titles  \
# 0  Service delivery sole criteria to compete for public office, says PM
# 1                                      Grand dialogue on polls proposed
# 2       Politicians advised to mend fences to prevent economic meltdown
# 3             Who cares about the economy in this political tug of war?
# 4       Jokes, racism: The many reactions to Humza Yousaf's appointment
#
#                                                                                                                                                                                                articleText  \
# 0  Prime Minister Shehbaz Sharif on Wednesday said politics in the country has been reduced to "meaningless rhetoric" and termed service delivery as the main criterion to compete for public office. \...
# 1  QUETTA:\n\nSenator Samina Mumtaz Zehri has said that as far as new elections are concerned in Pakistan, for the sake of the integrity and the interest of the country, all the stakeholders should h...
# 2  KARACHI:\n\nPakistan's economy has partially shut down and millions of people have lost jobs due to continuous political instability. The nation is destined to encounter hyperinflation with the do...
# 3  KARACHI:\n\nThe dollar rate is now a religious hymn, with everyone from rags to riches quoting it. A country’s currency is one of the key reflections of its economic strength or lack thereof. Chat...
# 4  Humza Yousaf made history after his appointment as the First Minister of Scotland --- being the first person of colour and the first Muslim to hold the coveted post. Of Pakistani descent, the new ...
#
#                         date_author
# 0        News Desk \nApril 19, 2023
# 1              APP \nApril 08, 2023
# 2  Salman Siddiqui \nApril 03, 2023
# 3       AAH Soomro \nApril 03, 2023
# 4      Social Desk \nMarch 30, 2023

# %%
entity_pairs = []

for i in tqdm(candidate_sentences["Titles"]):
  entity_pairs.append(get_entities(i))
# Out:
# 100%|██████████| 2998/2998 [00:32<00:00, 93.02it/s]

# %%
entity_pairs
# Out:
# [['public  PM', 'public  office'],
#  ['Grand  dialogue', 'polls'],
#  ['Politicians', 'economic  meltdown'],
#  ['Who', 'political  war'],
#  ['', 'many Humza appointment'],
#  ['Economic  stability', 'politics'],
#  ['Political  polarisation', 'superior  courts'],
#  ['', 'Dirty  SDGs'],
#  ['', ''],
#  ['', ''],
#  ['Abbasi', 'current  problems'],
#  ['', 'Supremacy  ills'],
#  ['High stakes election gamble', ''],
#  ['', '2023'],
#  ['youth', ''],
#  ['Political  bickering', 'flood relief effort'],
#  ['Political  parties', 'youth'],
#  ['lack', 'political  participation'],
#  ['we', 'lessons'],
#  ['', 'social  contract'],
#  ['political  chaos', ''],
#  ['Alvi', 'joint  sitting'],
#  ['', 'empathy'],
#  ['', 'civilian  supremacy'],
#  ['', 'dark  silhouettes'],
#  ['', 'stability'],
#  ['Lessons', ''],
#  ['', 'needed  Economy'],
#  ['who', 'world'],
#  ['', ''],
#  ['', 'floods'],
#  ['', 'politics'],
#  ['PDM economy', ''],
#  ['', ''],
#  ['Dialogue', 'political  uncertainty'],
#  ['', 'leadership'],
#  ['', 'time'],
#  ['Pakistan', 'India chess event'],
#  ['', ''],
#  ['Sanity', ''],
#  ['', 'PM Twitter'],
#  ['', 'ahead PTI Islamabad'],
#  ['nation', 'what'],
#  ['Fact Check', 'viral regime change'],
#  ['', 'Contradictions Pakistan'],
#  ['', 'ablaze Supreme ruling'],
#  ['', 'bizarre Shahbaz expletives'],
#  ['Satirical  song', 'Israel UAE Israel internet'],
#  ['Ban', 'political student Pakistan'],
#  ['Altaf Hussain', '2016 hate speech'],
#  ['New Jersey', 'Sikh  India'],
#  ['old George niece', 'home'],
#  ['Google', 'Philippine  election'],
#  ['Hypocrisy', 'cricket'],
#  ['', 'Rupee politics'],
#  ['', 'climate change'],
#  ['Politics', 'interests'],
#  ['', 'Dissecting PML N'],
#  ['Trees', 'fruit'],
#  ['Cornel West', 'spiritual  rot'],
#  ['', 'thyself'],
#  ['', ''],
#  ['', 'dignity'],
#  ['Nisar', 'PP-10 Rawalpindi seat'],
#  ['', 'people'],
#  ['LHC', 'arrest Rana Sanaullah'],
#  ['PDM', 'indecent burial'],
#  ['Islamic  party', 'Israel election'],
#  ['IHC', 'top slot election'],
#  ['Kangana Ranaut', ''],
#  ['PTI', 'allegedly Senate polls'],
#  ['', 'deputy chairman slot'],
#  ['', 'Gilani video case'],
#  ['handed trust Abbasi', 'handed trust institutions'],
#  ['Shibli', 'PM'],
#  ['NA speaker', 'PTI supporters'],
#  ['PTI', 'upcoming Senate chairman polls'],
#  ['', 'Senate polls'],
#  ['PTI', 'SC'],
#  ['', 'making PM politics'],
#  ['Masses', 'votes'],
#  ['Hamza', 'ranks'],
#  ['Shibli', 'Senate polls'],
#  ['', 'Senate polls'],
#  ['', 'Senate voting method'],
#  ['SC', 'sinking  ship'],
#  ['', 'uphold  Vawda'],
#  ['anxiety', 'govt'],
#  ['Maryam', '-  NA-75'],
#  ['Polling material', 'by polls'],
#  ['Senior leader Muhammad Anwar', 'away  London'],
#  ['claims', 'loan'],
#  ['Govt', 'presidential Senate ordinance'],
#  ['Political  parties', 'proportionate  Senate'],
#  ['', 'overseas record remittances'],
#  ['PPP', 'Senate election schedule'],
#  ['', 'politics'],
#  ['Rashid', 'assemblies'],
#  ['Asif Ali Zardari', 'fake accounts case'],
#  ['COVID inoculation campaign', ''],
#  ['Bilawal', 'labour  conditions'],
#  ['Govt', 'Machh incident'],
#  ['', ''],
#  ['alliance', 'unnatural FM Qureshi'],
#  ['armed  forces', 'politics'],
#  ['Tribune Poll', ''],
#  ['Opposition', ''],
#  ['Lahore rally Maryam', 'Pakistani  media'],
#  ['', ''],
#  ['Strong LG system', 'dynastic  politics'],
#  ['PDM arrests', 'ahead  rally'],
#  ['PML N', 'own  politics'],
#  ['', 'Elahi slams protesters'],
#  ['', ''],
#  ['', 'law'],
#  ['Pakistan Army', 'Constitution'],
#  ['', 'political  tension'],
#  ['', 'terrorism'],
#  ['Khawaja Asif', 'direction'],
#  ['', ''],
#  ['stakeholders', ''],
#  ['', 'more  bed'],
#  ['APC', 'oracle'],
#  ['Sindh minister', 'medicine prices'],
#  ['', 'CoD'],
#  ['Opposition', 'democracy'],
#  ['', 'Faraz belittles losers'],
#  ['final  Kaira', 'final  govt'],
#  ['', 'control'],
#  ['Opposition fires', 'black  laws'],
#  ['', 'international  order'],
#  ['', 'PPP  Covid-19'],
#  ['', 'Pakistan'],
#  ['MQM P', 'ethnic  divide'],
#  ['PTI govt', 'opposition'],
#  ['Opposition', 'Punjab  law'],
#  ['', 'false  claims'],
#  ['Mustafa Kamal', 'Karachi'],
#  ['', 'other  parties'],
#  ['', 'military'],
#  ['Sindh', 'Rs802.39b Karachi'],
#  ['PTI lawmaker', 'rain devastation'],
#  ['PSP chief', 'six point issues'],
#  ['Presidential system pleas', 'legal  debate'],
#  ['PML Abbasi', 'Karachi issues'],
#  ['', 'Taunsa'],
#  ['PTI', 'Muharram  Punjab'],
#  ['', 'Dire  minds'],
#  ['', 'economic  PTI'],
#  ['economy', ''],
#  ['PM Imran', 'departure'],
#  ['Ahsan', 'report'],
#  ['New  district', 'political  strife'],
#  ['PTI govt', 'development path'],
#  ['Sheikh Rashid', 'Opp future'],
#  ['Sindh', 'new  Karachi'],
#  ['Production order', 'opposition leader'],
#  ['', 'PPP minister IIOJK'],
#  ['PTI leader', 'Sindh cabinet Sindh resignation'],
#  ['Rashid', 'Buzdar ouster'],
#  ['PTI', 'modern  Sindh'],
#  ['Floods', 'city drains'],
#  ['COAS Bajwa', 'Sindh issues'],
#  ['NAB office attack', 'SC storming'],
#  ['', 'undecided LG polls'],
#  ['Sindh', 'electrocution deaths'],
#  ['PML N', 'tax SAPMs'],
#  ['PML N shoots', ''],
#  ['MQM P', 'arrest'],
#  ['Politics', 'powerless'],
#  ['', 'holy  governance'],
#  ['Stepping', 'Nawaz Sharif'],
#  ['PPP', 'NFC award notification'],
#  ['', 'entertainment'],
#  ['Murad Saeed', 'PPP Sindh'],
#  ['JI', 'HESCO'],
#  ['Naseem', 'third law time'],
#  ['', ''],
#  ['PML N MPs', 'NAB resignation'],
#  ['Consensus', 'Usman opponents'],
#  ['PPP', 'privatisation process'],
#  ['', 'PML N Bilawal'],
#  ['', 'Dual  cabinet'],
#  ['PTI move', 'PTV fee'],
#  ['ADB', 'worth loan Pakistan'],
#  ['Aamir Liaquat', 'NA seat'],
#  ['Rana Sanaullah', 'court appearance'],
#  ['', 'accountability process'],
#  ['', 'Uzair Baloch attention'],
#  ['PML  MPA', 'party leadership'],
#  ['Karachi', ''],
#  ['JIT report', 'PTI leader'],
#  ['', 'apex KE'],
#  ['NAB', 'also PTI projects'],
#  ['dismissal', 'supervision'],
#  ['PTI', 'KE'],
#  ['Abdullah Abdullah', 'Pakistan'],
#  ['', 'PML N'],
#  ['', 'one'],
#  ['MPAs Buzdar meeting', 'PML N'],
#  ['PSDP', 'Balochistan High Court'],
#  ['', ''],
#  ['', 'democracy'],
#  ['Opposition  mission', 'corruption'],
#  ['Sindh govt', 'budget'],
#  ['', 'BNP M BSO stage students'],
#  ['Allegations', 'MQM founder'],
#  ['govt', 'lies'],
#  ['Opposition', 'unanimously  budget'],
#  ['', 'austerity claims'],
#  ['Omar Ayub', 'wrong  question'],
#  ['', 'PPP MQM P intensifies'],
#  ['Bilawal', 'joint  budget'],
#  ['', 'Covid-19 drug hoarders'],
#  ['Syed Munawar Hassan', ''],
#  ['PML N lawmaker', 'inquiry'],
#  ['PPP minister', 'Covid deaths'],
#  ['', 'summons Khawaja June'],
#  ['', 'novel PTI coronavirus'],
#  ['', ''],
#  ['Imran', 'house'],
#  ['Shehbaz Gill', 'filthy Sindh hospitals'],
#  ['Fazl', 'Mengal govt'],
#  ['Centre', 'locusts'],
#  ['PBC', 'Isa case ruling'],
#  ['PTI govt negotiators', 'Mengal'],
#  ['Shehbaz', ''],
#  ['Centre reclaiming hospitals', ''],
#  ['Bilawal', 'judges'],
#  ['LHC', 'principal  PM'],
#  ['Govt', 'certain  anomalies'],
#  ['Centre', 'poor  Pakistan'],
#  ['Legal  Centre', 'hospitals'],
#  ['MPC rejects', 'NFC committee'],
#  ['bailable  warrants', 'Nawaz'],
#  ['Rabita Committee', 'Sindh govt'],
#  ['Urdu poetry', 'completely  India'],
#  ['Changes', 'NFC'],
#  ['blame Shibli', 'opposition'],
#  ['', 'prior demands assembly budget'],
#  ['Why  politics', ''],
#  ['minister', 'Sindh Assembly'],
#  ['', 'afraid  Covid-19'],
#  ['', 'federal  govt'],
#  ['PTI leaders', 'sugar mills'],
#  ['Shahzad Akbar', 'sugar report'],
#  ['Maryam', 'pic'],
#  ['', 'two SC judges'],
#  ['focal  person', ''],
#  ['', '18th Amendment'],
#  ['', 'focal health dept person'],
#  ['', 'Mayoral PTI tickets'],
#  ['Fresh NAB reference', 'Shehbaz'],
#  ['PML N', 'PTI'],
#  ['independently law minister', ''],
#  ['', ''],
#  ['NDMA', 'Covid-19 fight'],
#  ['', '10th NFC agenda Centre'],
#  ['', 'Retract Sindh Qureshi'],
#  ['PML N', 'medicine import medicine scandal'],
#  ['', 'Pakistan'],
#  ['Bilawal', 'coronavirus crisis'],
#  ['High Court issues', 'federal  government'],
#  ['measures', 'mind'],
#  ['PML N', '18th  amendment'],
#  ['PM  Imran', 'information helm'],
#  ['PM  Imran', 'foundation day'],
#  ['PTI incompetence', 'virus impact'],
#  ['Federal  govt', 'public  trust'],
#  ['Australia', 'COVID-19 probe'],
#  ['Permitting', 'risky  Governor'],
#  ['PML N', 'parliamentary  session'],
#  ['PPP leader', 'PTI budget'],
#  ['Indian  intelligence', 'Canadian  politicians'],
#  ['Covid-19', 'political  experts'],
#  ['Sindh govt catering', 'Firdous'],
#  ['', 'Sharp  dilemma'],
#  ['Sindh', 'better  support'],
#  ['Sindh minister', 'former Punjab remarks'],
#  ['this', 'crises'],
#  ['PPP minister', 'faulty testing kits'],
#  ['PTI MPA', ''],
#  ['', ''],
#  ['Shehbaz', 'daily wage earners'],
#  ['Buzdar', 'opposition'],
#  ['PML N', 'virus fund'],
#  ['ATC', 'Indian  spies'],
#  ['', '- party moot COVID-19'],
#  ['Shehbaz Sharif', 'quarantine post London'],
#  ['Shehbaz', 'Pakistan'],
#  ['', 'politics'],
#  ['PML N', 'NA session'],
#  ['', 'More project govts'],
#  ['Quarantine Sharjeel', 'Hyd centre'],
#  ['PML N', 'NAB resignation'],
#  ['', 'Mir Shakil case'],
#  ['PML  MPA', 'party discipline'],
#  ['', 'South Punjab'],
#  ['cities', 'large  villages'],
#  ['', ''],
#  ['', 'hibernation'],
#  ['long  she', 'long  silence'],
#  ['', 'questions USC Tareen'],
#  ['PPP leaders', 'MPA Buzdar moot'],
#  ['PML N', 'PTI govt'],
#  ['Qureshi', 'electoral  rules'],
#  ['Dr Adnan Malik', 'London'],
#  ['Bilawal', 'economic PTI policies'],
#  ['SHC', 'police matters'],
#  ['', 'PTI govt'],
#  ['PPP', 'women Sindh'],
#  ['Crisis mongers', 'PTI govt'],
#  ['', 'ourselves'],
#  ['Russian guru enters he', 'Kremlin'],
#  ['', 'Punjab'],
#  ['Bilawal', 'privatisation plan'],
#  ['Centre', 'administrative  JPMC'],
#  ['ECP', 'PML N PTI'],
#  ['Shaukat Yousafzai', 'P information minister'],
#  ['', 'legal  hitches'],
#  ['', 'Punjab wheat crisis'],
#  ['', 'Court orders time'],
#  ['political  activists', 'dating  apps'],
#  ['Sindh energy minister', 'Shikarpur suspension'],
#  ['belated PTI govt', 'Dr Farogh Naseem'],
#  ['', ''],
#  ['', 'possible Naya Karachi'],
#  ['Punjab  govt', 'plea'],
#  ['PTI leader', 'back  Bilawal'],
#  ['', 'funds'],
#  ['PML N', 'equanimity'],
#  ['K P govt', 'contempt case'],
#  ['', 'politics'],
#  ['Shahbaz', 'crisis'],
#  ['India', 'FATF meeting'],
#  ['', 'IGP uncertainty'],
#  ['PPP', 'Azadi March'],
#  ['ECP', 'founding  member'],
#  ['Plea', 'delimitation'],
#  ['Opposition parties', 'new K P'],
#  ['Siege mentality', 'K P Assembly'],
#  ['', 'functional  harmony'],
#  ['', 'goodwill ambassador'],
#  ['PML N', 'govt  drive'],
#  ['', 'responsible  farmers'],
#  ['I', 'govt'],
#  ['JUI F', 'govt  Feb'],
#  ['Omar Ayub Khan', 'Mr 10pc'],
#  ['IHC', 'three Iqbal bail pleas'],
#  ['Pindi lawmakers', 'development projects'],
#  ['', 'crime index'],
#  ['', 'PTI spokespersons meeting'],
#  ['PM Imran', 'national  reconciliation'],
#  ['he', 'resignation'],
#  ['Dr Kaleem transfer', 'room'],
#  ['plea', 'arrest footage'],
#  ['', 'abyss'],
#  ['PTI negotiators', 'back  fold'],
#  ['cardiac  procedures', 'twice  absence'],
#  ['Bilawal', 'IMF bailout package'],
#  ['Restoration', 'PTI negotiating committee'],
#  ['Bani Centre', 'BISP'],
#  ['', 'back railway Karachi'],
#  ['Jibran Nasir', 'PM Imran'],
#  ['Lawmakers', 'divided  opinion'],
#  ['hopeful  differences', 'PML Q'],
#  ['PTI govt lock horns', 'top  cop'],
#  ['PTI negotiators', 'allies'],
#  ['PTI govt', 'list'],
#  ['K P ministers', 'internal  matters'],
#  ['Path', 'ousted K P cabinet'],
#  ['PML N', 'govt contact protests'],
#  ['Federal  cabinet', 'top volte cop'],
#  ['Sindh', 'governor'],
#  ['P cabinet members', 'performance'],
#  ['PTI govt', 'looted month wealth'],
#  ['', 'ministry'],
#  ['Ousted K P minister', 'silence'],
#  ['Mayor Akhtar', 'PM struggles'],
#  ['PM Imran', 'Sindh'],
#  ['PM Imran', 'Sindh IGP Imam'],
#  ['P cabinet ministers', 'CM Mahmood'],
#  ['Probe', 'flour crisis'],
#  ['', 'PM Monday'],
#  ['', 'own PTI misery'],
#  ['PM Imran', 'foreign funding matter'],
#  ['PSP chief', 'divisive  politics'],
#  ['', 'Yousafzai  cabinet'],
#  ['PML N leader', 'Punjab flour gimmick'],
#  ['SHC', ''],
#  ['PTI govt', 'two MQM P demands'],
#  ['', 'table'],
#  ['New Sindh IGP', ''],
#  ['', 'flour crisis'],
#  ['Punjab  govt', 'medical  report'],
#  ['Sheikh Rashid', 'Buzdar row'],
#  ['', 'Kashmir referendum'],
#  ['Pakistani  politics', 'foreign  soil'],
#  ['Sindh  government', 'immediate police chief'],
#  ['PTI MNA', 'money'],
#  ['Troubles', 'PTI'],
#  ['restaurant photo', 'verbal  duel'],
#  ['', 'handed PTI allies'],
#  ['qualified  professionals', 'away govt firms'],
#  ['Cabinet', 'sugar mills case'],
#  ['NA', 'turncoat  allegations'],
#  ['Solving', 'problems'],
#  ['MQM P', 'us'],
#  ['Centre', 'developmental  projects'],
#  ['', 'vital  progress'],
#  ['Cabinet committee', 'case'],
#  ['', 'estranged PTI ally'],
#  ['', 'LG assembly'],
#  ['Khalid Maqbool Siddiqui', 'federal  minister'],
#  ['Tsai Ing wen', 'Taiwan election'],
#  ['experts', '2020'],
#  ['PTI', 'one  stone'],
#  ['NAB law tweaks', 'go ahead'],
#  ['', 'damage control'],
#  ['P cabinet expansion', 'party leaders'],
#  ['Parties', 'ahead NA CJSCS'],
#  ['', ''],
#  ['Making', 'politics'],
#  ['', 'services tenure'],
#  ['Pindi administration', 'N Senator property'],
#  ['COAS tenure bill', 'parliamentary  committees'],
#  ['', 'tenure bill'],
#  ['PTI minister', 'Saudi Arabia'],
#  ['economic NA speaker', 'economic  stability'],
#  ['', 'thana kutcheri thana culture'],
#  ['chief  Nawaz', 'Pakistan Army Act'],
#  ['IHC', 'challenging PTI ordinances'],
#  ['PTI govt', 'opposition'],
#  ['', ''],
#  ['PML N', 'Army Act amendments'],
#  ['PTI govt', 'MQM promises'],
#  ['', 'Happy New economy'],
#  ['Cabinet', 'Army Act'],
#  ['', 'still  Sindh'],
#  ['', ''],
#  ['NAB Amendment Ordinance', '2019  SC'],
#  ['Business support', 'DG ISPR'],
#  ['PTI govt', 'SC proposals'],
#  ['serving NAB law changes', ''],
#  ['', ''],
#  ['', 'delayed court challenge'],
#  ['irreparable  SC', 'in  hearing'],
#  ['star', 'Saif Ali Khan'],
#  ['', 'Ring Road Ring NAB'],
#  ['local  bodies', 'thumbs'],
#  ['', 'threat'],
#  ['Maryam Nawaz', 'abroad  aide'],
#  ['IHC grants', 'LNG case'],
#  ['PM Office', 'Malaysia summit'],
#  ['', ''],
#  ['Weekly  review', 'winning  end'],
#  ['Nawaz', 'complicated heart disease'],
#  ['Ousted LG representatives', 'Parliament'],
#  ['', 'current account businessmen'],
#  ['', 'civil  disorder'],
#  ['PML N', 'dethrone PM Imran'],
#  ['', 'CPEC route'],
#  ['Chohan', 'restraint'],
#  ['Why Imran Khan', ''],
#  ['monument', 'Karachi'],
#  ['', ''],
#  ['Opposition', 'pro ECP appointments'],
#  ['PML N', 'Lahore hospital Chohan'],
#  ['Arshad Malik video evidence', 'still Nawaz case'],
#  ['', 'more  Sharifs'],
#  ['announces', 'parliament'],
#  ['', 'short list post'],
#  ['PM', 'failed Sindh governance'],
#  ['PML N team', 'leadership'],
#  ['Hamid Khan', 'PTI'],
#  ['', 'apparition'],
#  ['', 'NAB Niazi woes'],
#  ['PML N', 'foreign funding case'],
#  ['', 'guidance'],
#  ['developed  countries', 'political climate goals'],
#  ['IHC', 'citizenship'],
#  ['NAB', 'Akram ECL'],
#  ['blood vessel', ''],
#  ['', 'govt telephones strategy'],
#  ['', 'Pakistan Taliban hostages'],
#  ['PML N', 'assets'],
#  ['PM Imran', 'CJP remarks'],
#  ['Politics', 'loot'],
#  ['CJP Khosa', 'PM judiciary'],
#  ['Opposition', 'P CM House'],
#  ['Political  parties', 'gas'],
#  ['', 'all'],
#  ['PML N', 'fresh  elections'],
#  ['PTI govt', 'court'],
#  ['Fazl', 'further fuels allies'],
#  ['LHC', 'defeat'],
#  ['PM Imran', 'legal LHC travel'],
#  ['', 'Khawaja NA'],
#  ['JUI F leaders', 'roadblock'],
#  ['Nawaz', 'consequences'],
#  ['', 'likely  Tuesday'],
#  ['Nawaz Sharif', 'more  tests'],
#  ['PTI govt', 'ransom'],
#  ['Pervaiz Elahi', 'pivotal F sit in'],
#  ['', 'Nawaz health'],
#  ['', 'PM resignation'],
#  ['Nawaz', 'medical  treatment'],
#  ['PML N', 'sit in'],
#  ['Azadi Chaudhrys', 'talks'],
#  ['Azadi Talks', ''],
#  ['Nawaz', 'release'],
#  ['', 'valid demands sans resignation'],
#  ['', ''],
#  ['PM', 'resignation'],
#  ['Azadi March', 'federal  capital'],
#  ['PTI govt', 'marchers'],
#  ['PTI govt', 'chaos'],
#  ['', 'PTI containers'],
#  ['Opposition parties', 'Islamabad'],
#  ['', 'riot capital Fazl'],
#  ['', 'threatening Bangladesh opposition PM'],
#  ['IHC', 'Firdous Ashiq Awan'],
#  ['People', 'mandate'],
#  ['JUI Islam', 'JUI Ansarul'],
#  ['Bilawal', 'PTI Imran'],
#  ['millions export containers', 'ahead Azadi March'],
#  ['marchers', 'Red Zone'],
#  ['', 'politics'],
#  ['JUI F Hafiz Hamdullah', 'NADRA'],
#  ['Maryam', 'Services Lahore'],
#  ['', "civil  '"],
#  ['PTI govt', 'treatment'],
#  ['US', 'Afghan election results'],
#  ['Nawaz', 'IVIG  Monday'],
#  ['JUI F', 'K P govt'],
#  ['businessmen', 'sit economy'],
#  ['', 'PM resignation'],
#  ['Federal  govt', 'Ansarul JUI militia'],
#  ['', 'ITP PML N diagnosis'],
#  ['Top  ministers', 'Azadi march'],
#  ['', 'unanimous  ouster'],
#  ['PTI govt team', 'separately  Fazl'],
#  ['PTI', 'organisational set up'],
#  ['Muqam', 'audit reports shatter'],
#  ['', 'low platelet count'],
#  ['PM Imran', ''],
#  ['Opposition', 'govt'],
#  ['Russian  accounts', '2020 US election'],
#  ['small  group', 'national  past'],
#  ['', 'Azadi march'],
#  ['Rahbar Committee', 'final govt talks'],
#  ['', 'harmful  economy'],
#  ['Pakistan', 'FATF time'],
#  ['JUI F', 'govt'],
#  ['PTI govt', 'Islam JUI militia'],
#  ['Khattak', 'opposition'],
#  ['Opposition parties', '2023'],
#  ['Bilawal', 'govt  protests'],
#  ['Shehbaz Sharif', 'full Azadi March'],
#  ['Khattak', 'negotiating  table'],
#  ['Islamabad March', 'itself'],
#  ['', 'CM Mahmood development'],
#  ['', 'populism'],
#  ['Fazl', 'march'],
#  ['IHC', 'Islamabad court'],
#  ['', 'govt Azadi Sindh'],
#  ['K P govt', 'Peshawar BRT probe'],
#  ['Centre empowers provinces', 'Azadi March'],
#  ['PML N', 'Azadi march'],
#  ['', 'govt  Oct'],
#  ['Khattak', 'term  polls'],
#  ['', 'ECP appointment'],
#  ['Trump', 'violently event meme'],
#  ['PML N', 'Azadi March'],
#  ['', 'MQM P Karachi'],
#  ['JUI F rally', 'PML N'],
#  ['Imran', 'march'],
#  ['Bangladesh issues', 'Nobel laureate'],
#  ['', 'foreign funding case'],
#  ['', 'mediation attempt'],
#  ['', 'same Azadi March'],
#  ['Fazl', 'Islamabad'],
#  ['PTI govt', 'aggressive  stance'],
#  ['', 'Qureshi IOK crisis'],
#  ['F Azadi March', 'IHC'],
#  ['PTI govt', 'progress'],
#  ['JUI F march', 'bind'],
#  ['', 'PML N proof'],
#  ['', 'Isa PTI plea'],
#  ['dangerous  that', 'trouble'],
#  ['', ''],
#  ['', ''],
#  ['Musharraf', 'politics'],
#  ['Sindh Assembly', 'MQM Sindh'],
#  ['PPP', 'solo  govt'],
#  ['Shehbaz', 'political  situation'],
#  ['', ''],
#  ['Khaqan Abbasi', 'jail Zardari'],
#  ['PML N', 'JUI F November'],
#  ['Bilour', 'PTI govt'],
#  ['JUI F', 'PTI govt home'],
#  ['', ''],
#  ['', ''],
#  ['Sindh CM', 'graft case'],
#  ['PPP', 'govt JUI F leader'],
#  ['just  Bilawal', 'political  prisoners'],
#  ['', 'govt Azadi Sept'],
#  ['', ''],
#  ['', 'mosquito gutter politics'],
#  ['Lyari', 'economic  development'],
#  ['PTI govt', 'accountability'],
#  ['President Macron', 'France'],
#  ['Opposition', 'political PTI govt'],
#  ['Court', '7 remand days'],
#  ['arrest', 'Kashmir failure'],
#  ['', 'leader Khursheed Shah'],
#  ['Demands', 'Sindh police schools'],
#  ['', 'plea'],
#  ['UK', 'Farooq murder case'],
#  ['Issue production Marri', 'Qaiser'],
#  ['Islamabad', 'New Delhi'],
#  ['PML N mulls', 'Azadi March'],
#  ['chairman Tahirul Qadri', 'politics'],
#  ['- Turkey premier', 'political  party'],
#  ['Karachi', ''],
#  ['', ''],
#  ['Interior minister', 'opposition parties'],
#  ['', '149 Centre Karachi'],
#  ['Bilawal', 'moral Islamabad Fazl'],
#  ['Urmila Matondkar', 'petty Indian politics'],
#  ['CM Murad', 'Punjab Sindh Assembly'],
#  ['PML N', 'release'],
#  ['govt KMC row', 'fumigation Karachi'],
#  ['China', 'political  tool'],
#  ['time  Safdar', 'Nawaz'],
#  ['ECP', 'Sept'],
#  ['PML N', 'danger zone'],
#  ['We', 'Kashmir'],
#  ['', 'advanced Sindh stage'],
#  ['', 'N slams case'],
#  ['Kashmir', 'Haider'],
#  ['Facebook', 'ahead US elections'],
#  ['joke', 'Karachi'],
#  ['', 'musical  chairs'],
#  ['Key  ally', 'ML I project'],
#  ['FATA ex lawmakers', 'oath'],
#  ['Where  Hindutva', '21st century India'],
#  ['Ahsan Iqbal', 'weak PTI policies'],
#  ['says', 'dialogue'],
#  ['', 'upcoming  APC'],
#  ['Gutter Rain', 'Centre'],
#  ['', 'fat Donald rally'],
#  ['PPP body', '14  Senate'],
#  ['', 'activist'],
#  ['PPP', ''],
#  ['Fazl', 'political opposition interests'],
#  ['Senate', ''],
#  ['Indian  aggression', 'Afghan peace process'],
#  ['', 'Rs11 US exchequer'],
#  ['Pakistan', 'Taliban'],
#  ['', 'economic  zone'],
#  ['Opposition', 'incarcerated production leaders'],
#  ['PTI', 'faux Maryam pas'],
#  ['Opposition', 'streets'],
#  ['New UK PM Johnson', 'October'],
#  ['Govt', 'sparing  Sanjrani'],
#  ['', ''],
#  ['', 'thaw US relations'],
#  ['', 'all'],
#  ['', 'commercial PM US'],
#  ['', 'Why paradigm politics'],
#  ['US House', 'Saudi weapons sales'],
#  ['Political  parties', 'tribal  districts'],
#  ['NAB', 'assets'],
#  ['Politicians govt employees', 'public  land'],
#  ['Change', 'hiring favouritism'],
#  ['', 'more  commission'],
#  ['Ex - minister', 'ruling  Erdogan'],
#  ['Riot police baton', 'Hong Kong protesters'],
#  ['Israel', 'state terrorism'],
#  ['', '68 blast rocks'],
#  ['', ''],
#  ['Imran', 'US July'],
#  ['', 'Dutch envoy lauds terrorism'],
#  ['plan rival Erdogan plan Istanbul', 'plan rival Erdogan plan party'],
#  ['corrupt', 'streets'],
#  ['Court', 'physical  July'],
#  ['’s', 'ourselves'],
#  ['Final  call', 'economy'],
#  ['', 'debt pile up'],
#  ['Zardari', 'economic  policy'],
#  ['Opposition', 'budget'],
#  ['who', 'murder'],
#  ['doors', 'Nawaz Sharif'],
#  ['PPP MPAs', 'Sindh Assembly session'],
#  ['', '- election Florida'],
#  ['Opposition', 'led  end'],
#  ['SJC', 'new Qazi Faez Isa'],
#  ['2019  PTI', 'disgruntled  Balochistan'],
#  ['PTI govt', 'approval'],
#  ['This', 'just  personalities'],
#  ['', 'Pakistan permission'],
#  ['Reference', 'SCBA chairman'],
#  ['', 'money launderers'],
#  ['terrorists', ''],
#  ['India PM aircraft', ''],
#  ['Trump', 'US Mexico migrant deal'],
#  ['separatist  trial', ''],
#  ['he', ''],
#  ['Govt', 'political  opponents'],
#  ['', 'US envoy civilians'],
#  ['NAB', 'Zardari'],
#  ['Trump Macron friendship', ''],
#  ['PTI govt', 'economic  survey'],
#  ['', '144 North Waziristan'],
#  ['', 'Abe Iran'],
#  ['Zardari', 'fake accounts case'],
#  ['', 'wide ANP inflation'],
#  ['', 'Shehbaz'],
#  ['Biden support', 'fierce party backlash'],
#  ['Islamabad bar', 'judges'],
#  ['', 'govt Lal Haveli'],
#  ['', 'rising Marriyum inflation'],
#  ['friends', 'money'],
#  ['Wahab', 'Karachi'],
#  ['PTI leaders', 'top SJC judges'],
#  ['', 'petrol price hike'],
#  ['Bilawal', 'merged  districts'],
#  ['', ''],
#  ['Sitharaman aide Shah', 'home department'],
#  ['PML N', 'Nawaz health'],
#  ['Narendra Modi', 'second  term'],
#  ['MQM P', 'urban  Sindh'],
#  ['Justice Isa', 'reference reports'],
#  ['Deletion', 'people'],
#  ['', 'Modi'],
#  ['', 'new  provinces'],
#  ['incapable  PM', 'clash'],
#  ['Modi', 'party violence'],
#  ['NAB', 'bulletproof vehicles'],
#  ['allegations', 'corruption'],
#  ['Congress', 'poll Rahul defeat'],
#  ['', 'election win'],
#  ['fans', 'town saffron'],
#  ['Pakistan renews', 'talks'],
#  ['NAB', 'bulletproof cars case'],
#  ['Firdous', 'NAB'],
#  ['', 'Maryam thanks tea'],
#  ['opposition parties', ''],
#  ['’s', ''],
#  ['', '30 % 2030'],
#  ['PML N', 'key party Monday'],
#  ['Cow', 'Muslim  IOK'],
#  ['Pakistan', 'restraint'],
#  ['', 'S nukes'],
#  ['Women lawmakers', 'NA panel'],
#  ['PTI', 'south Punjab bill'],
#  ['coalition allies', 'Iran threat'],
#  ['PML N', 'amnesty scheme'],
#  ['', 'Formal PML offing'],
#  ['Pakistan', 'Iran US tussle'],
#  ['Balochistan chief absense', 'Senate panel'],
#  ['PML N', 'new  provinces'],
#  ['PM  Imran', 'inclusive development efforts'],
#  ['K P CM', 'olive opposition MPAs'],
#  ['', 'six point PTI'],
#  ['Zardari', 'fake accounts case'],
#  ['Sheikh Rashid', 'federal  cabinet'],
#  ['', 'Bright  moon'],
#  ['', '10 million Trump Congress'],
#  ['', 'IMF IMF'],
#  ['', 'Istanbul vote -'],
#  ['PM', 'LG change'],
#  ['', 'diminish govt day'],
#  ['Punjab Local Government Act', 'old  law'],
#  ['Pakistan', 'incompetence'],
#  ['', 'longer PML N'],
#  ['that', ''],
#  ['Ruling party candidate', 'Muslim  posts'],
#  ['re', ''],
#  ['high treason case', 'June'],
#  ['economic  Bilawal', 'economic  mess'],
#  ['PTI', 'power'],
#  ['PTI govt', 'Khyber Pakhtunkhwa'],
#  ['Army', 'legal  PTM'],
#  ['Defence brother', 'provincial  minister'],
#  ['Richard Lugar', 'foreign policy 87'],
#  ['MPA', 'reserved  seats'],
#  ['', 'Local Punjab Assembly'],
#  ['Sindh  CM', 'even  PTI'],
#  ['', 'Punjab Assembly'],
#  ['Russia', 'new Venezuela sanctions'],
#  ['PTI', 'gas bills'],
#  ['PPP', 'sexist PM Bilawal'],
#  ['Umar', 'economic  plan'],
#  ['Egyptians', 'overwhelmingly  rule'],
#  ['Where CM input', 'opposition'],
#  ['Marriyum Aurangzeb', 'history'],
#  ['Turkish poll body', 'sacked party voters'],
#  ['China', 'Belt PM Forum'],
#  ['PM', 'scathing  Iran'],
#  ['Congress', 'him'],
#  ['interior  minister', 'Daniel murder'],
#  ['Housing scheme', 'PM Shehbaz'],
#  ['Fazl', 'Islamabad'],
#  ['Hope  Iran', 'Pakistan  elements'],
#  ['NAB', 'politics'],
#  ['US', 'Russian  meddling'],
#  ['Ghulam Sarwar', 'aviation ministry'],
#  ['Shah', 'interior  minister'],
#  ['China', 'participating debt nations'],
#  ['PTI govt', 'foreign  pacts'],
#  ['Imran Khan', 'cabinet'],
#  ['Pakistan', 'dictatorship'],
#  ['Political  meddling', 'closure'],
#  ['', 'Fresh Cabinet focus'],
#  ['Bangladesh film star', 'electioneering'],
#  ['', 'Bilawal Asad removal'],
#  ['', 'bomb blast'],
#  ['', 'led Yemen war'],
#  ['Canada conservatives', 'Alberta Trudeau'],
#  ['AK Party', 'Istanbul elections'],
#  ['PPP', 'IMF talks'],
#  ['Rind', 'Balochistan allies'],
#  ['she', 'numbers'],
#  ['internal  rifts', 'Punjab  appointments'],
#  ['who', 'final  count'],
#  ['', 'real election crusader democracy'],
#  ['army', ''],
#  ['clothing fire', 'White House emergency'],
#  ['', ''],
#  ['fake accounts NAB', 'IHC'],
#  ['Hamza', 'NAB'],
#  ['protestors', 'further  demos'],
#  ['PTI minister', 'Hamza'],
#  ['Bashir', 'arrest'],
#  ['Zardari', 'PTI govt'],
#  ['it', 'PM Imran'],
#  ['Indian  SC', 'classified Rafale papers'],
#  ['Shehbaz Sharif', 'quick  London'],
#  ['Pakistan Housing Authority', 'federal  nod'],
#  ['old Amritsar India', 'old Amritsar massacre'],
#  ['', 'election machine'],
#  ['', 'Zardari patch up'],
#  ['Incompetent PTI govt', 'bankruptcy'],
#  ['', 'led tax amnesty scheme'],
#  ['Police', 'more hate speech case'],
#  ['Erdogan', 'Istanbul vote results'],
#  ['BJP', '1.4trn infrastructure boost election'],
#  ['Sharifs', 'NRO'],
#  ['led  govt', 'let accountability'],
#  ['confident  parties', 'PPP march PTI govt'],
#  ['Mongolian Pot', ''],
#  ['JUI F leadership', 'party  polls'],
#  ['', 'Captain team'],
#  ['How  elections', 'winding  Israel'],
#  ['Political  parties', 'aside  Karachi'],
#  ['PML N', 'Sharif residence'],
#  ['PM  initiative', 'Hyderabad'],
#  ['Deadly Maoist attack', 'Indian India election'],
#  ['Imran', 'English  speech'],
#  ['India', 'jailed  Pakistanis'],
#  ['PPP', 'political  vendetta'],
#  ['CM Mahmood', 'tribal PTI areas'],
#  ['', 'tribal ticket allocation areas'],
#  ['', 'tax amnesty scheme'],
#  ['', 'takeaways  Pakistan'],
#  ['Imran', 'finally ECP posts'],
#  ['PM Imran', 'Qureshi Tareen conflict'],
#  ['', ''],
#  ['', 'back Iran track'],
#  ['Opposition', 'public  issues'],
#  ['Qureshi', 'official  meetings'],
#  ['China', 'Europe'],
#  ['PM  politics', 'NAB'],
#  ['PM', 'Sharifs'],
#  ['PM Imran', 'Rs162 billion development Karachi'],
#  ['', 'away  theft'],
#  ['Britain', 'Brexit options'],
#  ['BJP', 'Samjhauta Express bombing'],
#  ['- terror machinery', ''],
#  ['', 'apart ECP appointments'],
#  ['Maduro regime', 'public  office'],
#  ['link', 'Pulwama attack'],
#  ['remarks', 'PM'],
#  ['Modi', 'election blitz'],
#  ['UK govt', 'third Brexit deal Friday'],
#  ['', 'court postpones Shehbaz'],
#  ['Bilawal', 'accountability'],
#  ['', 'banned reviews outfits'],
#  ['NAB', 'sugar mills case'],
#  ['Nawaz', 'medical  treatment'],
#  ['PML N fires', 'Imran Khan'],
#  ['Nawaz condition', ''],
#  ['Bilawal', 'fascist opponents traitors'],
#  ['', 'political parties blitz cartoons'],
#  ['', 'Explainer Golan Heights'],
#  ['Zardari', 'govt performance'],
#  ['', 'equal  law'],
#  ['Modi', 'holy  elections'],
#  ['Promised  tsunami', 'PTI'],
#  ['sublingual  Maryam', 'sublingual  pain'],
#  ['', 'World Puppetry Day'],
#  ['', 'defusing Pak India tensions'],
#  ['', 'home turf'],
#  ['Hamza slams', 'health'],
#  ['', 'nationalists K P'],
#  ['Shehbaz', 'Model Town case'],
#  ['Seven', 'Bangladesh'],
#  ['', 'Indian  voter'],
#  ['', ''],
#  ['US Senate', 'wall'],
#  ['doubts govt', 'banned  groups'],
#  ['', 'Cordial Kartarpur Pakistan'],
#  ['', ''],
#  ['personal  physician', ''],
#  ['', 'same  page'],
#  ['Sindh Assembly', 'lowest participation rate'],
#  ['', 'Circular Rs1.27b daily'],
#  ['honorable  Nawaz', 'brother'],
#  ['Indian opposition parties', 'armed  forces'],
#  ['PTI MPA', 'Sindh'],
#  ['Opposition', 'mock assembly session'],
#  ['Bilawal', 'NA HR'],
#  ['US', 'one visa year'],
#  ['Canada budget minister', 'fresh  Trudeau'],
#  ['Shehbaz', 'economy'],
#  ['Air strikes', 'more Lok Sabha seats'],
#  ['Indian  threat', 'political  decisions'],
#  ['Parliamentary  leaders', 'Indian  aggression'],
#  ['', 'more  India'],
#  ['Political  bigwigs', 'Model Town JIT'],
#  ['PML N', 'IHC verdict'],
#  ['', ''],
#  ['', 'standing committees elections'],
#  ['World', 'situation'],
#  ['Govt  opposition', 'NA'],
#  ['', 'patriotism'],
#  ['India', 'irresponsibly Pulwama attack'],
#  ['', 'PM India'],
#  ['', 'young  homes'],
#  ['', 'next  Friday'],
#  ['PTI govt', 'tenure'],
#  ['witnesses', 'recent  Ranjhani'],
#  ['Priyanka magic', 'debut India'],
#  ['Main', 'nationalist  murder'],
#  ['that', 'Thai rebuke'],
#  ['second Trump Kim summit', 'Korean War'],
#  ['peace Pakistan', 'quietly  Kabul'],
#  ['Facebook', 'ahead India election'],
#  ['Shah', 'ill  arrest'],
#  ['Presidential  system', 'form'],
#  ['Politics', 'illness'],
#  ['arrest', 'opposition speechless'],
#  ['Erdogan', 'democracy'],
#  ['PML N', 'Sheikh Rashid'],
#  ['lip people', 'lip service'],
#  ['Govt', 'Hajj subsidy'],
#  ['', 'cabinet meeting'],
#  ['Saudi crown prince', 'Feb'],
#  ['IHC', 'disqualification'],
#  ['', 'Fresh PML N arrest'],
#  ['May', 'Brexit divorce deal'],
#  ['PTI', 'special  wealth'],
#  ['', 'Supreme Court'],
#  ['', 'minimum Rahul Gandhi poor'],
#  ['PML N', 'foreign loans details'],
#  ['', 'Modi Facebook post'],
#  ['West', 'him'],
#  ['Kaira', 'land grabbing'],
#  ['imperialist  dictation', 'progress'],
#  ['18th ANP', 'PTI govt'],
#  ['PPP who', 'PTI MPA'],
#  ['Fate', 'NA session'],
#  ['Govt', 'medical  health'],
#  ['Peshawar commissioner', ''],
#  ['Senators', 'blistering  budget'],
#  ['', ''],
#  ['Kareena Kapoor Khan', 'politics'],
#  ['India', 'opposition election alliance'],
#  ['Senator Kamala Harris', 'presidential  run'],
#  ['PM', 'Qatari  Doha'],
#  ['Military  courts', 'bargaining NRO'],
#  ['I', 'PAC'],
#  ['', ''],
#  ['US', 'North Korea'],
#  ['', 'open Farooq arms'],
#  ['', 'PML Q PML Punjab'],
#  ['Indian  opposition', 'joint  Modi'],
#  ['', 'rare  unanimity'],
#  ['', 'skeptical PML N'],
#  ['Fawad', 'Sindh resignation'],
#  ['NRO PML N leaders', 'govt'],
#  ['PTI minister', 'son'],
#  ['PA Opposition', 'ECL issue'],
#  ['', 'PML N incompetence'],
#  ['PTI', 'disqualification Zardari'],
#  ['Bizenjo', 'grand PPP alliance'],
#  ['', ''],
#  ['who', 'public  mandate'],
#  ...]

# %%
entity_pairs[10:20]
# Out:
# [['Abbasi', 'current  problems'],
#  ['', 'Supremacy  ills'],
#  ['High stakes election gamble', ''],
#  ['', '2023'],
#  ['youth', ''],
#  ['Political  bickering', 'flood relief effort'],
#  ['Political  parties', 'youth'],
#  ['lack', 'political  participation'],
#  ['we', 'lessons'],
#  ['', 'social  contract']]

# %%
def get_relation(sent):

  doc = nlp(sent)

  # Matcher class object 
  matcher = Matcher(nlp.vocab)

  #define the pattern 
  pattern = [{'DEP':'ROOT'}, 
            {'DEP':'prep','OP':"?"},
            {'DEP':'agent','OP':"?"},  
            {'POS':'ADJ','OP':"?"}] 

  matcher.add("matching_1", [pattern]) 

  matches = matcher(doc)
  k = len(matches) - 1

  span = doc[matches[k][1]:matches[k][2]] 

  return(span.text)

# %%
relations = [get_relation(i) for i in tqdm(candidate_sentences['Titles'])]
# Out:
# 100%|██████████| 2998/2998 [00:33<00:00, 88.77it/s]

# %%
pd.Series(relations).value_counts()[:50]
# Out:
# says           137
# urges           33
# seeks           30
# is              26
# claims          26
# tells           26
# asks            24
# Imran           21
# rejects         21
# accuses         17
# vows            16
# demands         16
# calls           16
# set             15
# slams           15
# warns           14
# takes           14
# announces       14
# wants           13
# joins           12
# decides         11
# sees            11
# politics        11
# challenges      10
# calls for       10
# advises         10
# meets            9
# join             9
# denies           9
# gives            9
# refuses          8
# sets             8
# meet             8
# condemns         8
# Nawaz            8
# throws           7
# sworn            7
# launches         7
# govt             7
# passes           7
# Politics of      7
# Trump            7
# Bilawal          7
# lashes           6
# see              6
# agree            6
# assures          6
# need             6
# visit            6
# Is               6
# dtype: int64

# %%
len(relations)
# Out:
# 2998

# %%
relations
# Out:
# ['says',
#  'proposed',
#  'advised',
#  'cares about',
#  'Jokes',
#  'links to',
#  'takes',
#  'politics behind',
#  'politics',
#  'turbulence',
#  'says',
#  'panacea for',
#  'politicking',
#  'room',
#  'is',
#  'dents',
#  'urged',
#  'examined',
#  'learnt',
#  'Call for new',
#  'Rashid',
#  'cleared',
#  'Politics of',
#  'moment',
#  'Iraq',
#  'Usher in',
#  'learnt',
#  'Charter of',
#  'Gorbachev',
#  'polarisation',
#  'Politicking amid',
#  'Money in',
#  'fiddles',
#  'crisis',
#  'urged',
#  'Takeaways from',
#  'stitch in',
#  'pulls out',
#  'Greed',
#  'prevail',
#  'son in',
#  'raid',
#  'is',
#  'Is viral',
#  'galore in',
#  'media ablaze',
#  'WATCH',
#  'divides',
#  'causes',
#  'goes on',
#  'passes',
#  'shot at',
#  'ban political',
#  'define',
#  'slide',
#  'politics of',
#  'uses',
#  'politics',
#  'laden with',
#  'resigns from',
#  'Know',
#  'Politics',
#  'slap on',
#  'plans',
#  'Politics of',
#  'grants pre',
#  'gets',
#  'becomes',
#  'throws',
#  'refuses',
#  'expels',
#  'Haideri for',
#  'inclusion of',
#  'says',
#  'says',
#  'condemns',
#  'seeks',
#  'rejects',
#  'challenges',
#  'Imran',
#  'take',
#  'says',
#  'terms',
#  'evidence of',
#  'prerogative',
#  'provide',
#  'Tribunals uphold',
#  'see',
#  'accuses',
#  'concludes',
#  'passes',
#  'is fake',
#  'hostage with presidential',
#  'have proportionate',
#  'lauds overseas',
#  'expresses',
#  'drag',
#  'predicts',
#  'granted permanent',
#  'begins',
#  'censures',
#  'hits',
#  'landscape',
#  'destined',
#  'says armed',
#  'is biggest',
#  'resignations',
#  'takes',
#  'Politics',
#  'break',
#  'planned',
#  'buried',
#  'govt for',
#  'pointless',
#  'Governance',
#  'guided by',
#  'Raging political',
#  'Resurging',
#  'spoken against',
#  'chaos',
#  'suffer',
#  'monkeys',
#  'moved',
#  'slams',
#  'Recalling',
#  'comes',
#  'APC as',
#  'says',
#  'Imran',
#  'broadside against',
#  'End of',
#  'funds',
#  'Reforming',
#  'accuses',
#  'Iqbal',
#  'grills Punjab',
#  'Sindh',
#  'seeks',
#  'dependent on other',
#  'obsession of',
#  'launches',
#  'points',
#  'puts',
#  'trigger legal',
#  'says',
#  'politician from',
#  'plans post',
#  'need',
#  'Punjab',
#  'set',
#  'regrets',
#  'seeks',
#  'intensifies political',
#  'put',
#  'sees',
#  'gives',
#  'ignored',
#  'slams',
#  'demands',
#  'snubs',
#  'demands',
#  'expose',
#  'meet',
#  'likens',
#  'PTI undecided',
#  'blames',
#  'demands',
#  'talk',
#  'condemns',
#  'is',
#  'Institutions',
#  'be fatal',
#  'rejects',
#  'Politics of',
#  'points',
#  'urges',
#  'sworn',
#  'Pakistan',
#  'demands',
#  'evades',
#  'turn on',
#  'delegation',
#  'nationals in',
#  'rejected',
#  'warns of',
#  'give',
#  'exempted from',
#  'Opposition',
#  'PTI',
#  'takes',
#  'persist',
#  'claims',
#  'PTI',
#  'probe into',
#  'casts',
#  'sets',
#  'visit',
#  'Is',
#  'Why',
#  'creates',
#  'challenged in',
#  'Crackdown',
#  'Opening',
#  'is',
#  'warns',
#  'rally in',
#  'proved true',
#  'defends',
#  'rejects',
#  'contests',
#  'asks',
#  'tiff between',
#  'agree on joint',
#  'Action',
#  'passes',
#  'challenges',
#  'seeks',
#  'Asif on',
#  'advice',
#  'leaks',
#  'tries',
#  'laments',
#  'seeks',
#  'taking',
#  'set',
#  'fail',
#  'says',
#  'is premature',
#  'seeks',
#  'summons principal',
#  'intends',
#  'faulted for poor',
#  'process',
#  'reconstituted',
#  'issued',
#  'censures',
#  'is',
#  'acceptable',
#  'tells',
#  'session',
#  'despised',
#  'warns',
#  'Sindh',
#  'discuss provincial',
#  'call for',
#  'says',
#  'lashes',
#  'govt',
#  'decides',
#  'Review of',
#  'Sindh',
#  'hopefuls',
#  'ready',
#  'lashes',
#  'says',
#  'watchdogs',
#  'help in',
#  'tilts in',
#  'remarks',
#  'calls for',
#  'Covid-19 in',
#  'blasts',
#  'notices to federal',
#  'downtrodden',
#  'warns',
#  'appoints',
#  'reminds',
#  'worsened',
#  'lost public',
#  'says',
#  'Sindh',
#  'rejects',
#  'urges',
#  'used',
#  'change global',
#  'accuses',
#  'horns of',
#  'fare',
#  'retorts to former',
#  'is',
#  'lashes',
#  'says',
#  'politics',
#  'urges',
#  'tells',
#  'sets',
#  'extends physical',
#  'pushes for',
#  'goes into',
#  'return to',
#  'time for',
#  'submits',
#  'delays for',
#  'facilities',
#  'demands',
#  'Nawaz in',
#  'denies',
#  'MPs',
#  'turned into large',
#  'province',
#  'Out of',
#  'says',
#  'plan',
#  'meet after',
#  'ensured',
#  'complains',
#  'attacked in',
#  'censures',
#  'serves',
#  'Projects of',
#  'failed',
#  'topple',
#  'Fending for',
#  'playing for',
#  'Bilawal',
#  'vows',
#  'decides against',
#  'refuses',
#  'removed as',
#  'repatriation',
#  'govts behind',
#  'ECP',
#  'turn to',
#  'demands',
#  'throws',
#  'politics',
#  'Umar',
#  'rejects',
#  'hits',
#  'Centre',
#  'absorbs',
#  'release',
#  'Nepotism in',
#  'Sindh',
#  'humiliated in',
#  'Crime on',
#  'rejects',
#  'takes',
#  'challenges',
#  'unite on new',
#  'takes',
#  'quest for functional',
#  'Khan for',
#  'distances',
#  'losses to',
#  'stands by',
#  'initiate anti',
#  'refers to',
#  'gives',
#  'call',
#  'Karachi on',
#  'Imran',
#  '’s',
#  'claims',
#  'remains',
#  'dismissed',
#  'slide into',
#  'see',
#  'postponed',
#  'demands',
#  'recommended',
#  'warns of',
#  'Centre',
#  'sends',
#  'pay',
#  'resolved',
#  'again',
#  'asked',
#  'insists',
#  'sacked for',
#  'spelt',
#  'launch mass',
#  'does',
#  'refuses',
#  'given',
#  'gives',
#  'made subservient',
#  'breaks',
#  'asks',
#  'mollycoddles',
#  'agrees',
#  'sacked for',
#  'faults',
#  'Imran',
#  'govt responsible',
#  'moves',
#  'vows',
#  'dismisses',
#  'left',
#  'says',
#  'expresses',
#  'Boot on',
#  'appointed',
#  'Shehbaz',
#  'rejects',
#  'throws',
#  'Imran',
#  'is',
#  'requests immediate',
#  'accuses',
#  'begun',
#  'unleashes verbal',
#  'job',
#  'stay',
#  'gives',
#  'enveloped in',
#  'be',
#  'fade',
#  'reviews',
#  'Independence of',
#  'recommends',
#  'swings into',
#  'PTI',
#  'announces',
#  'landslide in',
#  'warn',
#  'kills',
#  'get',
#  'Act',
#  'causes',
#  'bill',
#  'bills',
#  'work',
#  'Assembly',
#  'seals',
#  're',
#  'Resentment in',
#  'says',
#  'says',
#  'Imran',
#  'extension',
#  'gives',
#  'allows',
#  'reshuffle',
#  'gives',
#  'assures',
#  'Year',
#  'approves',
#  'decade in',
#  'challenges',
#  'challenged in',
#  'for',
#  'ignores',
#  'rejected',
#  'money',
#  'resort',
#  'fears',
#  'calls',
#  'radar',
#  'left',
#  'Undeterred by',
#  'allow',
#  'bail to',
#  'vetoed',
#  'Iqbal',
#  'comes to',
#  'diagnosed with complicated',
#  'protest outside',
#  'deficit',
#  'policies',
#  'seeks',
#  'slams',
#  'urges',
#  'is',
#  'outraged',
#  'reference',
#  'offers quid',
#  'claims',
#  'considered in',
#  'relief for',
#  'boycott of',
#  'govt',
#  'hits',
#  'reaches',
#  'refuses',
#  'Thoughts at',
#  'nexus',
#  'seeks',
#  'Govt',
#  'says developed',
#  'told',
#  'wants',
#  'blocked',
#  'Bilawal',
#  'thanks',
#  'dares',
#  'stops',
#  'plunder',
#  'asks',
#  'starts',
#  'slam',
#  'Accountability',
#  'seeks fresh',
#  'committing',
#  'claim further',
#  'ruling',
#  'asks legal',
#  'motion',
#  'get into',
#  'AGP',
#  'Nawaz likely',
#  'undergo more',
#  'asking for',
#  'plays',
#  'Imran',
#  'Fazl',
#  'fly',
#  'continue',
#  'upbeat about',
#  'fail',
#  'delays',
#  'Imran ready',
#  'ban',
#  'snubs',
#  'rallies into federal',
#  'Ijaz',
#  'warns of',
#  'bars',
#  'bicker over',
#  'kitting',
#  'stalwart',
#  'serves',
#  'stolen',
#  'IHC',
#  'vows',
#  'orders worth',
#  'agrees',
#  'Assault on',
#  'declared',
#  'moved to',
#  'poll',
#  'vows',
#  'advises',
#  'given',
#  'moves',
#  'worried about',
#  'sticks to',
#  'bans',
#  'govt',
#  'decry',
#  'Opposition unanimous',
#  'meet',
#  'announces new',
#  'claims',
#  'Sharif in',
#  'says',
#  'sets',
#  'targeted',
#  'plundered national',
#  'N in',
#  'offer',
#  'Politics of',
#  'Qureshi',
#  'asks',
#  'decides',
#  'warns',
#  'wait till',
#  'announces',
#  'announces',
#  'hopes',
#  'is',
#  'Khan for',
#  'Breaking',
#  'rejects',
#  'throws',
#  'Fazl likely',
#  'rejects',
#  'deal with',
#  'decides',
#  'Bilawal',
#  'rules',
#  'orders',
#  'attacks',
#  'meet',
#  'pushes for',
#  'exposes',
#  'tasks',
#  'warrant for',
#  'pleas for',
#  'Imran',
#  'Opposition',
#  'see',
#  'compel',
#  'timing of',
#  'challenged in',
#  'focusing on',
#  'puts',
#  'leaders',
#  'team',
#  'Rashid',
#  'politics',
#  'demerits',
#  'plans',
#  'condemns',
#  'oppose',
#  'discuss current',
#  'reshuffle in',
#  'awarded',
#  'proposes',
#  'calls',
#  'agree',
#  'questions',
#  'development',
#  'excuses',
#  'claims',
#  'demands',
#  'APC on anti',
#  'demise',
#  'After',
#  'rejects',
#  'crushing',
#  'reaches',
#  'decries political',
#  'extends',
#  'ploy',
#  'arrests',
#  'replaced by',
#  'IHC',
#  'agrees',
#  'tells',
#  'refuses',
#  'participating in',
#  'announces',
#  'promises new',
#  'talked about',
#  'moves',
#  'rules',
#  'mulls',
#  'distances',
#  'resigns from',
#  'lashes',
#  'demands',
#  'hampers',
#  'says',
#  'quotes',
#  'puts',
#  'says',
#  'have',
#  'efforts',
#  'shuffle in',
#  'Watching',
#  'tightens',
#  '’s on',
#  'Game of musical',
#  'accuses',
#  'take',
#  'steer 21st',
#  'accuses',
#  'engage',
#  'Shehbaz likely',
#  'sets',
#  'Trump',
#  'meets',
#  'Ahsan',
#  'switch',
#  'used',
#  'says',
#  'Qureshi',
#  'visit',
#  'fulfil',
#  'PM for',
#  'demands',
#  'having',
#  'set',
#  'says',
#  'tries',
#  'speech',
#  'visit',
#  'Accountability for',
#  'drive',
#  'shift in',
#  'Trump',
#  'break',
#  'decides',
#  'booked for',
#  'sparks',
#  'cases against',
#  'quits',
#  'charge',
#  'says',
#  'people',
#  'cricket',
#  'set',
#  'progress in',
#  'defeat',
#  'wants',
#  'grants',
#  'Let',
#  'be',
#  'constitution of',
#  'urges',
#  'forms',
#  'jailed for',
#  'closed on',
#  'forged',
#  'Trump',
#  'agrees on',
#  'receives new',
#  'reaches',
#  'spent',
#  'is',
#  'Modi',
#  'alleges',
#  'Imran',
#  'arrested',
#  'ministry',
#  'reveals more',
#  'draws',
#  'says',
#  'Bilawal',
#  'heads to',
#  'calls for',
#  'died',
#  'convenes',
#  'Section',
#  'heads to',
#  'arrested in fake',
#  'launches',
#  'Return of',
#  'draws fierce',
#  'condemns',
#  'drive',
#  'denounces',
#  'performed',
#  'calls',
#  'say clueless',
#  'slams',
#  'issues',
#  'Fast',
#  'takes',
#  'keeps',
#  'sworn',
#  'asks',
#  'seeks',
#  'schemes',
#  'invite from',
#  'Politics of new',
#  'says',
#  'praises',
#  'continues',
#  'aim',
#  'backs',
#  'congratulates',
#  'Modi',
#  'Modi',
#  'allows',
#  'asks',
#  'Bilawal for',
#  'heats',
#  'Let',
#  'vehicles',
#  'calls key',
#  'lynching',
#  'urges',
#  'Trump',
#  'walk out',
#  'opposed',
#  'appear',
#  'turns',
#  'alliance of',
#  'pick',
#  'irks',
#  'backs',
#  'urges',
#  'extends olive',
#  'Raisani',
#  'Rashid',
#  'hints at more',
#  'side of',
#  'signatures',
#  'slams',
#  'orders',
#  'champions',
#  'hopes of local',
#  'organisations',
#  'handed',
#  'part of',
#  'Provocations',
#  'quits Australian',
#  'unopposed',
#  'adjourned till',
#  'says',
#  'help',
#  'forms',
#  'signals legal',
#  'takes',
#  'dies at',
#  'demands',
#  'act',
#  'be from',
#  'Treasury',
#  'asks',
#  'confessed to',
#  'urges',
#  'takes robust',
#  'approve',
#  'asks',
#  'claims',
#  'rejects',
#  'welcomes',
#  'faces scathing',
#  'says',
#  'was',
#  'planned by',
#  'warns of',
#  'Qureshi',
#  'consider',
#  'says',
#  'refuses',
#  'Brig',
#  'says',
#  'guards',
#  'shakes',
#  'is under',
#  'drives',
#  'faces in',
#  'expelled for',
#  'nation after',
#  'candidate',
#  'bill',
#  'win',
#  'submits',
#  'asks',
#  'asks',
#  'Considered',
#  'grow over Punjab',
#  'Explainer',
#  'power',
#  'resigns',
#  'officials',
#  'shame',
#  'tells',
#  'appears before',
#  'vow further',
#  'says',
#  'ousted by',
#  'agree',
#  'keep',
#  'rejects',
#  'leaves for',
#  'gets federal',
#  'says',
#  'greases',
#  'Fazl',
#  'Aimal',
#  'govt',
#  'seek more',
#  'sees',
#  'makes',
#  'be',
#  'vows',
#  'back',
#  'launched',
#  'shows',
#  'marvels at',
#  'work',
#  'set',
#  'blasts',
#  'is illegal',
#  'fears for',
#  'takes',
#  'releases',
#  'accuses',
#  'chalks',
#  'finalises',
#  'U',
#  'Back from',
#  'writes',
#  'bars',
#  'politicians',
#  'relations',
#  'decides',
#  'slams',
#  'expands into',
#  'revolves around',
#  'tells',
#  'announces',
#  'Getting',
#  'says',
#  'backs acquittal',
#  'Maleeha',
#  'govt',
#  'strips',
#  'found',
#  'clarified',
#  'launches',
#  'plans third',
#  'indictment of',
#  'vows',
#  'crackdown on',
#  'grills',
#  'Abbasi',
#  'broadside against',
#  'worsening',
#  'slams',
#  'smartphones with political',
#  'is',
#  'discuss',
#  'Everyone equal',
#  'chooses',
#  'seems',
#  'says',
#  'congratulates',
#  'role in',
#  'scion',
#  'remarks on',
#  'Pashtun',
#  'records',
#  'shot dead',
#  'Team',
#  'Cricket',
#  'rebukes',
#  'will',
#  'talks between',
#  'Rafique',
#  'says personal',
#  'On',
#  'sets new',
#  'debt',
#  'tells',
#  'attack',
#  'criticises',
#  'holds mock',
#  'elected',
#  'reduces',
#  'quits in fresh',
#  'urges',
#  'vindicated',
#  'puts',
#  'back armed',
#  'Risk of more',
#  'fail',
#  'announces',
#  'Politics',
#  'workers',
#  'step',
#  'continue',
#  'Unfair',
#  'affected',
#  'lauds',
#  'trauma',
#  'released from',
#  'wants',
#  'largest',
#  'draws',
#  'arrested',
#  'faces',
#  'end',
#  'warns',
#  'boosts political',
#  'sees',
#  'be acceptable',
#  'deplorable',
#  'left',
#  'accuses',
#  'asks',
#  'Government',
#  'draws',
#  'summons',
#  'arrive in',
#  'admits',
#  'challenge to',
#  'seek',
#  'using special',
#  'Sharif',
#  'pledges',
#  'demands foreign',
#  'politician',
#  'muscle',
#  'accuses',
#  'says',
#  'tells',
#  'Police on',
#  'adjourned',
#  'forms new',
#  'feud',
#  'launch',
#  'recognise',
#  'Is',
#  'dismisses',
#  'announces presidential',
#  'meets Qatari',
#  'issue',
#  'Stop',
#  'blunder',
#  'says',
#  'accept',
#  'Rifts between',
#  'stages giant',
#  'Treasury',
#  'leaders skeptical',
#  'repeats',
#  'continue',
#  'advises',
#  'session',
#  'accuses',
#  'retracts',
#  'meets',
#  'victimisation',
#  'demands',
#  ...]

# %% [markdown]
# # Health

# %%
candidate_sentences2 = pd.read_csv("/content/drive/MyDrive/HealthNews.csv")
candidate_sentences2.shape
# Out:
# (2997, 3)

# %%
candidate_sentences2.head()
# Out:
#                                                                                                                                                                                                articleText  \
# 0  LAHORE:\n\nTo mark World Health Day, a special awareness seminar was organized on Friday at Fatima Jinnah Medical University.\nCaretaker Provincial Health Ministers Dr Javed Akram and Dr Jamal Nas...
# 1  PESHAWAR:\n\nA high level 13-member committee has been formed by the Khyber-Pakhtunkhwa (K-P) government to implement the dengue action plan 2023 across the province.\nTalking to The Express Tribu...
# 2  PESHAWAR:\n\nThe number of Covid-19 cases have been on the rise in Khyber-Pakhtunkhwa (K-P) once again as 12 new cases have been reported in the last 24 hours, an official of the health department...
# 3  QUETTA:\n\nBalochistan cabinet on Friday approved health card program for all families of the province to ensure quality healthcare facilities for the local residents.\nChief Minister Balochistan,...
# 4  PESHAWAR:\n\nThe number of Covid-19 has jumped up once again in Khyber-Pakhtunkhwa (K-P) including Peshawar, an official of the Health Department said here Saturday.\nHe observed that despite the ...
#
#                           date_author  \
# 0  Our Correspondent \nApril 08, 2023
# 1  Our Correspondent \nApril 06, 2023
# 2  Our Correspondent \nApril 01, 2023
# 3      Syed Ali Shah \nApril 01, 2023
# 4  Our Correspondent \nMarch 26, 2023
#
#                                     News Title
# 0  ‘29% of population suffering from diabetes’
# 1            K-P readies plan to combat dengue
# 2      Covid-19 cases on the rise in K-P again
# 3     Balochistan cabinet approves health card
# 4     Seven new Covid-19 cases detected in K-P

# %%
entity_pairs2 = []

for i in tqdm(candidate_sentences2["News Title"]):
  entity_pairs2.append(get_entities(i))
# Out:
# 100%|██████████| 2997/2997 [00:28<00:00, 106.05it/s]

# %%
relations2 = [get_relation(i) for i in tqdm(candidate_sentences2['News Title'])]
# Out:
# 100%|██████████| 2997/2997 [00:29<00:00, 102.36it/s]

# %%
pd.Series(relations2).value_counts()[:50]
# Out:
# says              64
# study             51
# reports           28
# ways              25
# claims            21
# seeks             19
# cases             17
# is                17
# urges             16
# told              15
# sees              13
# Govt              13
# say               13
# vows              12
# help              11
# finds             11
# reasons           11
# tips              11
# urged             10
# foods             10
# set               10
# gets              10
# launches          10
# sets               9
# benefits of        9
# be                 9
# tests positive     9
# continues          8
# are                8
# drive              8
# test positive      8
# continue           8
# launched           8
# die of             8
# surpasses          8
# orders             8
# approves           8
# shows              8
# get                8
# Coronavirus        7
# Day                7
# hits               7
# puts               7
# found              7
# govt               7
# reveals            7
# takes              7
# surface in         7
# gives              7
# need               7
# dtype: int64

# %%
relations2
# Out:
# ['% of',
#  'plan',
#  'cases on',
#  'approves',
#  'cases',
#  'awaited',
#  'provide',
#  'set',
#  'employs new',
#  'opens in',
#  'fortification',
#  'reactivates',
#  'dilemma',
#  'care',
#  'outlined',
#  'start anti',
#  'formed',
#  'begins in',
#  'stunted in',
#  'miss anti',
#  'disease on',
#  'held',
#  'reviewed',
#  'planning',
#  'Minister for universal',
#  'worries over',
#  'plays',
#  'get',
#  'test',
#  'warns of',
#  'given legal',
#  'Govt',
#  'priorities',
#  'rises as',
#  'faces',
#  'sign',
#  'found in',
#  'discussed',
#  'die of',
#  'plague',
#  'made',
#  'centres',
#  'Steer',
#  'reviewed',
#  'continues',
#  'Growth',
#  'elevated',
#  'cases',
#  'stages',
#  'get',
#  'campaign',
#  'safety of',
#  'inaugurates',
#  'warn against',
#  'need assistive',
#  'Pakistanis',
#  'cause of',
#  'clarifies',
#  'held',
#  'claims',
#  'vaccinated against',
#  'alarming',
#  'respite from',
#  'rue governmental',
#  'Funds',
#  'targets',
#  'launches',
#  'children at',
#  'recovered from',
#  'visits',
#  'prepares national',
#  'delivers',
#  'Alvi for early',
#  'enters',
#  'drive on',
#  'vaccinated against',
#  'types of',
#  'surface',
#  'see',
#  'cases',
#  'call for mass',
#  'expo',
#  'outbreak likely',
#  'Call for',
#  'Crackdown on illegal',
#  'gets digital',
#  'ponds',
#  'fee',
#  'sets',
#  'faces',
#  'claims',
#  'response from',
#  'Children',
#  'launched',
#  'marks',
#  'paint gloomy',
#  'decline in Covid',
#  'warn of',
#  'highlights',
#  'Govt',
#  'detected in',
#  'reviews anti',
#  'rush',
#  'Experts for early',
#  'taken into',
#  'built on',
#  'camps',
#  'Covid on',
#  'needed for',
#  'leave',
#  'expedites',
#  'tips',
#  'suffer in',
#  'says',
#  'booked for',
#  'filed for',
#  'hamstrung by',
#  'asked',
#  'spurt',
#  'launched',
#  'is rampant',
#  'mars',
#  'plan',
#  'die of',
#  'reveals',
#  'Looming',
#  'joins',
#  'Work on',
#  'season',
#  'cops',
#  'calls for',
#  'continue',
#  'partner',
#  'Call for',
#  'tightens',
#  'found in',
#  'struggles',
#  'face financial',
#  'vaccinated against',
#  'facility',
#  'demand',
#  'held',
#  'Piles of',
#  'prioritises',
#  'call for',
#  'develops',
#  'teams',
#  'devises',
#  'gets',
#  'partner',
#  'told',
#  'reviewed',
#  'has more',
#  'instigates',
#  'feasts',
#  'Providing',
#  'count',
#  'Everything',
#  'cure',
#  'ways',
#  'tips',
#  'provides safe',
#  'Try',
#  'paves',
#  'Reasons',
#  "'s",
#  'accords',
#  'tips',
#  'step towards',
#  'Edit',
#  'shares',
#  'pens',
#  'is problematic',
#  'ways',
#  'begin human',
#  'reasons',
#  'says',
#  'lose',
#  'Peerzada on',
#  'Move',
#  'foods',
#  'wants',
#  'crises',
#  'are',
#  'Presenting',
#  'signs',
#  'boosters',
#  'regime during',
#  'sheds',
#  'munch',
#  'Skincare',
#  'faces',
#  'change',
#  'benefits of navel',
#  'reasons',
#  'find',
#  'outbreak',
#  'quarantine',
#  'reasons',
#  'impacts',
#  'admitted to',
#  'held',
#  'launch anti',
#  'steps',
#  'ways',
#  'Revitalising',
#  'nuts',
#  'Coffee',
#  'warns',
#  'speak',
#  'ways',
#  'health in',
#  'informs',
#  'detox',
#  'AstraZeneca',
#  'hacks',
#  'Benefits of',
#  'things',
#  "'s",
#  'exercises',
#  'drinks',
#  'Shed',
#  'stay fit',
#  'says',
#  'Combining',
#  'fruits',
#  'tips',
#  'lauded for',
#  'guide to',
#  'responsibility',
#  'supplied',
#  'Drink',
#  'Edit',
#  'encourages',
#  'protect against',
#  'midwives',
#  'remedies',
#  'digitalise',
#  'benefits of',
#  'sent',
#  'get Covid',
#  'wants',
#  'officials',
#  'throws',
#  'cites',
#  'highlight',
#  'reasons',
#  'surpass',
#  'Ways',
#  'Ways',
#  'sees',
#  'criticised over',
#  'gave',
#  'is',
#  'reports',
#  'fears',
#  'test new',
#  'claims',
#  'begins',
#  'begins',
#  'am better',
#  'rises among',
#  'ratio at',
#  'cases',
#  'sets',
#  'spikes with',
#  'introduce',
#  '%',
#  'see',
#  'adds',
#  'allowed',
#  'buys additional',
#  'EU',
#  'Foods',
#  'appoint',
#  'sees most',
#  'gets',
#  'urges better',
#  'seek',
#  'clash as latter',
#  'find',
#  'what',
#  'frays',
#  'readies',
#  'denies',
#  'seeks',
#  'hit',
#  'reports',
#  'need',
#  'filed against',
#  'claims',
#  'orders',
#  'study',
#  'vows universal',
#  'stay below',
#  'allocated',
#  'Moderna',
#  'told',
#  'hours in',
#  'plazas',
#  'top',
#  'filled',
#  'PPPA',
#  'recorded',
#  'rises along',
#  'dept',
#  'join final',
#  'termed',
#  'die of',
#  'drive',
#  'making',
#  'Pharmacies',
#  'warns',
#  'conducts clinical',
#  'Policy',
#  'have',
#  'says',
#  'die from',
#  'Meditation',
#  'hits',
#  'vaccine',
#  'study',
#  'president',
#  'Law on premarital',
#  'exceed',
#  'imposes',
#  'Denmark',
#  'says',
#  'locks',
#  'Rouhani',
#  'highlighted',
#  'tests positive',
#  'decrees new',
#  'sees',
#  'develops essential',
#  'ICU',
#  'gets',
#  'opens for',
#  'probe',
#  'fears second',
#  'open temporary',
#  'boycott',
#  'crosses',
#  'says',
#  'teleclinic',
#  'rights',
#  'continues',
#  'approves second',
#  'skincare',
#  'removed from',
#  'approach to pandemic',
#  'overcome',
#  'Kaleem',
#  'Iran nuclear',
#  'Marvis of',
#  'revokes',
#  'formed',
#  'begins',
#  'Study',
#  'ways',
#  'myths about',
#  'hit',
#  'caught',
#  'test',
#  'see',
#  'seeks',
#  'getting',
#  'closed in',
#  'passes',
#  'mulls',
#  'issues',
#  'types of',
#  'help',
#  'assist in',
#  'firm on',
#  'recipes for full',
#  'says',
#  'start',
#  'hits',
#  'says',
#  'has',
#  'sets',
#  'says',
#  'suffer from',
#  'warns',
#  'exceeds',
#  'things',
#  'closed across',
#  'MPs',
#  'reports',
#  'existed',
#  'decides',
#  'virus positive',
#  'grieve stillborn',
#  'Europe',
#  'Keep',
#  'surpasses',
#  'study',
#  'getting suboptimal',
#  'capital',
#  'mask',
#  'surpasses',
#  'battle',
#  'shows',
#  'concerning',
#  'honours',
#  'ways',
#  'Schools likely',
#  'helping',
#  'dies after',
#  'wipe',
#  'reported in',
#  'drive in',
#  'resigns over',
#  'premier',
#  'seeks',
#  'continue',
#  'clueless',
#  'ways',
#  'cause',
#  'masks',
#  'mystery of',
#  'timings',
#  'upgraded',
#  'reopen after',
#  'harm',
#  'CHANGEMAKERS',
#  'discussed',
#  'held on',
#  'professionals',
#  'finds',
#  'director',
#  'produces first',
#  'make',
#  'laid',
#  'puts',
#  'rise',
#  'cautions',
#  'be ready',
#  'ramped',
#  'tourists',
#  'exercises',
#  'called',
#  'must',
#  'registers',
#  'recall of',
#  'signs',
#  'dilemma',
#  'lifesaving',
#  'dons',
#  'estimated',
#  'foods',
#  'says',
#  "'s",
#  'antibodies',
#  'turnaround',
#  'push',
#  'cases at',
#  'says',
#  'benefits of',
#  'vaccine unlikely',
#  'hit',
#  'stress',
#  'completes',
#  'faces rocky',
#  'discharged from',
#  'benefits of',
#  'patients at high',
#  'is',
#  'geared',
#  'reports',
#  'give',
#  'complete anti',
#  'finds',
#  'has successful',
#  'study',
#  'be',
#  'patients of',
#  'ways',
#  'take',
#  'tests positive',
#  'sought',
#  'developer cautious',
#  'ways',
#  'helps immune',
#  'claims around',
#  'crowd',
#  'children',
#  'ease',
#  'Try red',
#  'risks',
#  'Foods',
#  'say',
#  'results of',
#  'gives',
#  'warns of dangerous',
#  'hub',
#  'infections',
#  'reports',
#  'kills',
#  'adults',
#  'provide',
#  'claims',
#  'pass',
#  'cuts',
#  'CM',
#  'issues',
#  'handled',
#  'denies Chinese',
#  'is',
#  'nod for',
#  'calls for more',
#  'transmit',
#  'edges',
#  'says',
#  'tests positive',
#  'reports',
#  'keep',
#  'says',
#  'join virtual',
#  'says',
#  'series of',
#  'reports',
#  'imposes second',
#  'changes',
#  'pay',
#  'Businesses',
#  'Sindh',
#  'Sindh',
#  'Demystifying',
#  'drop across',
#  'told',
#  'spike in Indian',
#  'need',
#  'reduce',
#  'sees highest',
#  'get new',
#  'says',
#  'is healthier',
#  'Imran',
#  'project',
#  'continue',
#  'surpasses',
#  'tested for',
#  'ill in',
#  'made',
#  'set',
#  'expanded to posh',
#  'fall for fifth',
#  'declare new',
#  'continue',
#  'says',
#  'head in',
#  'promote specialist',
#  'OPDs',
#  'seeks',
#  'goes into',
#  'soars to',
#  'sees European',
#  'inmates in',
#  'reports',
#  'areas',
#  'surpasses',
#  'urges',
#  'reports',
#  'fires',
#  'be',
#  'hotspots',
#  'disappears from',
#  'receives',
#  'earmarked for',
#  'mulls',
#  'capacity',
#  'goes live',
#  'pleads for',
#  'set',
#  'Stigma',
#  'visits',
#  'receive mixed',
#  'funding',
#  'study',
#  'mulls',
#  'turns',
#  'surpasses',
#  'shut after',
#  'reach',
#  'reports',
#  'reimpose',
#  'sees',
#  'sees',
#  'Rs14.52b',
#  'hospitals',
#  'govt',
#  'tests',
#  'feared in',
#  'want cleaner',
#  'get stylish',
#  'cases in',
#  'begin',
#  'reports highest',
#  'collapses in',
#  'says asymptomatic',
#  'cases',
#  'recommends',
#  'need',
#  'dismiss',
#  'cases',
#  'discusses special',
#  'see',
#  'Over',
#  'urges',
#  'row over',
#  'survives',
#  'top',
#  'COMSATS',
#  'tops',
#  'slows to',
#  'believe',
#  'says',
#  'overtakes',
#  'spread top',
#  'jumps to',
#  'needed for',
#  'says',
#  'offers futuristic',
#  'warns against needless',
#  'warn of',
#  'completes',
#  'sees',
#  'morphing into',
#  'spike',
#  'frustrates Saudi',
#  'emerge from',
#  'tops',
#  'abandons',
#  'pays',
#  'says',
#  'reports',
#  'likely',
#  'suggests',
#  'emerge in',
#  'say',
#  'sees highest',
#  'approves',
#  'extend',
#  'patient',
#  'hunt pandemic',
#  'loses philanthropic',
#  'drop',
#  'overtake',
#  'rush',
#  'beats',
#  'delay',
#  'CM',
#  'succumbs to',
#  'reports first',
#  'witnesses',
#  'open',
#  'trigger',
#  'enters 20th',
#  'test positive',
#  'investigate',
#  'makes',
#  'succumbs to',
#  'surpasses',
#  'backs',
#  'sees',
#  'cases',
#  'study',
#  'need',
#  'appeals to',
#  'surpasses',
#  'repatriated from',
#  'reflect different',
#  'recovers from',
#  'For',
#  'vows',
#  'percentage of positive',
#  'urges social',
#  'increase',
#  'cases',
#  'push nationwide',
#  'lands',
#  'records highest',
#  'contracts',
#  'found',
#  'Technology for',
#  'are',
#  'guarantee',
#  'doubles',
#  'seek provisional',
#  'gives',
#  'puts',
#  'cases',
#  'found dead',
#  'Things',
#  'LIVE',
#  'find little',
#  'seeks',
#  'recover from',
#  'protest over unpaid',
#  'calls for sustained',
#  'marks highest',
#  'sought for',
#  'suspends',
#  'health',
#  'launch',
#  'recover from',
#  'pledges',
#  'increases',
#  'see',
#  'warns against',
#  'Outbreak at',
#  'finds',
#  'Wear',
#  'carried',
#  'look like',
#  'rubbishes',
#  'sees',
#  'sets',
#  'priority in',
#  'rises in several',
#  'cause behavioral',
#  'increases',
#  'approves',
#  'cases',
#  'patient in',
#  'says',
#  'fear',
#  'spends over',
#  'continue',
#  'orders',
#  'conundrum',
#  'billion',
#  'surface in',
#  'aiming for',
#  'Check',
#  'way',
#  'bans',
#  'says',
#  'call for',
#  'sees',
#  'fight',
#  'accuses',
#  'Govt',
#  'tackle',
#  'returns to',
#  'frontline',
#  'soars past',
#  'begin',
#  'filled',
#  'rise across Arab',
#  'reaches',
#  'recovers with',
#  'Hospitals',
#  'delivers healthy',
#  'masked',
#  'be',
#  'soars to',
#  'buy',
#  'tests positive',
#  'jump past',
#  'nears',
#  'study',
#  'orders random',
#  'suggests',
#  'workers',
#  'doubt',
#  'Sindh',
#  'gives',
#  'urges',
#  'hit',
#  'hits',
#  'breaks',
#  'succumbs to',
#  'surface in',
#  'calls for gradual',
#  'NICVD under',
#  'hope',
#  'identifies potential',
#  'sees',
#  'had',
#  'flypasts',
#  'tops',
#  'wishes speedy',
#  'begin',
#  'launches',
#  'take',
#  'emerge in',
#  'nears',
#  'urge',
#  'Oxford',
#  'imposes',
#  'seeks',
#  'says',
#  'says',
#  'reaches new',
#  'pile',
#  'prepares',
#  'responds to',
#  'delivers more',
#  'set for',
#  'benefits of',
#  'Doctor',
#  'falls',
#  'says pandemic',
#  'stay healthy',
#  'donate',
#  'continue',
#  'spend major',
#  'issues',
#  'children',
#  'records',
#  'urges',
#  'gives',
#  'People in',
#  'launches',
#  'spotted in',
#  'service',
#  'hopes',
#  'doctors',
#  'ways',
#  'loses',
#  'do',
#  'demands',
#  'become',
#  'stimulus',
#  'rethink',
#  'seeks',
#  'deprives',
#  'worries over',
#  'closed',
#  'silent on',
#  'cooperation',
#  'increase in',
#  'key to',
#  'pledges',
#  'export',
#  'records',
#  'warns',
#  'sees sharp',
#  'cops',
#  'thinking of',
#  'govt',
#  'shows',
#  'becomes',
#  'sees',
#  'brought for',
#  'push',
#  'raises',
#  'Release of essential',
#  'heroes of',
#  'are',
#  'thinks',
#  'Think',
#  'keeps',
#  'experiencing vivid',
#  'mounts',
#  'cases',
#  'reports',
#  'allocates',
#  'appeals for more',
#  'Masood',
#  'reports',
#  'jump to',
#  'Sindh likely',
#  'look',
#  'claim Indonesian',
#  'urged',
#  'kits',
#  'challenge of',
#  'told',
#  'says',
#  'face',
#  'unveils',
#  'ends',
#  'LIVE',
#  'Johnson with',
#  'has',
#  'improve',
#  'loses',
#  'warns against',
#  'clash with',
#  'join',
#  'ways',
#  'proposes',
#  'pushed unproven',
#  'recover from',
#  'Five',
#  'urges',
#  'issues detailed',
#  'drops for first',
#  'secures',
#  'Trump',
#  'services',
#  'cases',
#  'deprives critical',
#  'says',
#  'clears',
#  'claim anti',
#  'rises to',
#  'tell',
#  'suggests',
#  'warn of',
#  'urges',
#  'plan',
#  'pays',
#  'Brewery',
#  'develop',
#  'urges',
#  'surpass',
#  'urged',
#  'highlights autistic',
#  'introduces',
#  'tells',
#  'reaches',
#  'quacks free',
#  'reaches',
#  'urged',
#  'open',
#  'plans',
#  'chloroquine as possible',
#  'is',
#  'fight',
#  'die of',
#  'fall',
#  'launches',
#  'ordered',
#  'Edhi',
#  'pilgrims',
#  'raising',
#  'tests positive',
#  'return via',
#  'issues',
#  'launches',
#  'foods',
#  'Rouhani',
#  'unveils',
#  'announces',
#  'crisis',
#  'hacks',
#  'looms',
#  'affects',
#  'announces',
#  'take',
#  'turned',
#  'Is',
#  'became',
#  'claims',
#  'habits of',
#  'Being on',
#  'doctors',
#  'lead',
#  'jump by',
#  'People reluctant',
#  'exceed',
#  'Separate',
#  'tops',
#  'continue',
#  'jump as',
#  'decides',
#  'denies surgical',
#  'suspended',
#  'divided over',
#  'Shops close',
#  'Coronavirus',
#  'reports',
#  'says',
#  'Latest on',
#  'overtake',
#  'afoot',
#  'save',
#  'believes old',
#  'decides',
#  'determined',
#  'tests positive',
#  'shut',
#  'Coronavirus',
#  'efforts',
#  'Bring',
#  'pledges',
#  'postponed',
#  'fails as',
#  'hit by',
#  'forces',
#  'urges',
#  'Imran',
#  'rescheduled after',
#  'last until',
#  'calls for national',
#  'threat',
#  'tells',
#  'reports',
#  'study',
#  'develop',
#  'spells',
#  'suspends',
#  'catch',
#  'facilities',
#  'Sindh',
#  ...]

# %% [markdown]
# # Fake News

# %%
candidate_sentences3 = pd.read_excel("/content/drive/MyDrive/pakistani_dataset_consolidated.xlsx")
candidate_sentences3.shape
# Out:
# (12008, 13)

# %%
candidate_sentences3.tail()
# Out:
#                                                                                                                                 URL  \
# 12003                            https://www.factchecker.in/fact-check/electricity-power-tariff-punjab-costliest-aap-leaders-758403
# 12004                                      https://www.altnews.in/old-fake-message-about-ndtv-prannoy-roy-and-his-wife-viral-again/
# 12005            https://www.altnews.in/werewolf-sculpture-shared-with-unrelated-video-from-pak-believed-to-be-an-incident-from-mp/
# 12006  https://scroll.in/article/998893/fact-check-is-electricity-in-punjab-really-the-countrys-most-expensive-as-aap-leaders-claim
# 12007                   https://www.boomlive.in/fake-quote-on-communal-hatred-falsely-credited-to-jammu-and-kashmir-police-officer/
#
#                                                                       Title  \
# 12003              Is Electricity Costliest in Punjab as AAP Leaders Claim?
# 12004      Previous Story False message makes claims about NDTV and its ...
# 12005  Werewolf sculpture shared with unrelated video from Pak believed ...
# 12006    Fact check: Is electricity in Punjab really the country's most ...
# 12007       Fake Quote On Communal Hatred Falsely Credited To Jammu and ...
#
#                                                                                              Text  \
# 12003  Punjab doesnt charge the most for electricity in the country, Maharashtra and Rajasthan do
# 12004                     NDTV's Prannoy Roy is Pakistani, his wife Radhika's real name is Rahila
# 12005                                        'Werewolf was spotted in Bandhavgarh, Madhya Pradesh
# 12006                                            Electricity in Punjab is the costliest in India.
# 12007              Muslim majority areas do not attack and beat to death Hindus, said Patiala SP.
#
#                 Review Date Textual Rating  Publisher Site  Publisher Name  \
# 12003  2021-06-29T13:06:36Z          False  factchecker.in  FactChecker.in
# 12004  2021-06-11T00:00:00Z          False      altnews.in        Alt News
# 12005  2021-06-23T00:00:00Z          False      altnews.in        Alt News
# 12006  2021-07-01T08:00:00Z          False       scroll.in       Scroll.in
# 12007  2019-08-30T15:59:58Z           Fake     boomlive.in       BOOM Live
#
#                  Claim Date                                       Claimant  \
# 12003  2021-06-29T13:06:36Z  AAP Leader Raghav Chadha and MP Bhagwant Mann
# 12004  2016-06-20T00:00:00Z                                   Social Media
# 12005  2016-06-20T00:00:00Z                               WhatsApp forward
# 12006  2021-07-01T08:00:00Z    AAP leaders Raghav Chadha and Bhagwant Mann
# 12007  2019-08-30T15:59:58Z                                  Facebook post
#
#       Content Published At Author Url to Image
# 12003     NaN          NaN    NaN          NaN
# 12004     NaN          NaN    NaN          NaN
# 12005     NaN          NaN    NaN          NaN
# 12006     NaN          NaN    NaN          NaN
# 12007     NaN          NaN    NaN          NaN

# %%
candidate_sentences3.dtypes
# Out:
# URL               object
# Title             object
# Text              object
# Review Date       object
# Textual Rating    object
# Publisher Site    object
# Publisher Name    object
# Claim Date        object
# Claimant          object
# Content           object
# Published At      object
# Author            object
# Url to Image      object
# dtype: object

# %%
candidate_sentences3['Title'].isnull()
# Out:
# 0         True
# 1         True
# 2        False
# 3        False
# 4        False
#          ...
# 12003    False
# 12004    False
# 12005    False
# 12006    False
# 12007    False
# Name: Title, Length: 12008, dtype: bool

# %%
candidate_sentences3 = candidate_sentences3.fillna('Imran Khan is Ex Prime Minister')

# %%
candidate_sentences3['Title'] = candidate_sentences3['Title'].astype('str')

# %%
entity_pairs3 = []

for i in tqdm(candidate_sentences3["Title"]):
  entity_pairs3.append(get_entities(i))
# Out:
# 100%|██████████| 12008/12008 [02:05<00:00, 95.74it/s]

# %%
relations3 = [get_relation(i) for i in tqdm(candidate_sentences3["Title"])]
# Out:
# 100%|██████████| 12008/12008 [02:06<00:00, 94.70it/s]

# %%
pd.Series(relations3).value_counts()[:50]
# Out:
# says          294
# is            292
# Check         169
# Is             81
# shared as      63
# Says           58
# Times          53
# 's             46
# In             43
# takes          40
# say            40
# are            40
# shows          39
# Are            37
# approves       37
# Shared As      37
# Cricket        36
# claims         32
# tells          32
# seeks          31
# release of     29
# Modi           29
# asks           29
# set            29
# be             29
# gets           28
# India          28
# ’s             26
# make           24
# has            23
# Watch          23
# show           22
# was            22
# Explained      21
# Report         21
# News           21
# arrests        21
# demands        20
# claim          20
# leads          20
# Was            20
# shared         19
# have           18
# Video Of       17
# urges          17
# begins         17
# kills          17
# Passed         17
# seek           16
# get            16
# dtype: int64

# %%
relations3
# Out:
# ['is',
#  'is',
#  'claims',
#  'Claim',
#  'Is Fake',
#  'Check',
#  'Check',
#  'Check',
#  'give',
#  'Modi',
#  'Check',
#  'Check',
#  'Check',
#  'Check',
#  'Revived Amid',
#  'Check',
#  'linked to',
#  'linked to',
#  'linked to',
#  'Check',
#  'Is',
#  'Video From',
#  'Check',
#  'Check',
#  'Check',
#  'Check',
#  'Check',
#  'Claim',
#  'denied',
#  'Check',
#  'Check',
#  'Share',
#  'Is from',
#  'Check',
#  'Passed',
#  'Check of',
#  'claim',
#  'Waved at',
#  'Waved at',
#  'Sarma',
#  'Sarma',
#  'Check',
#  'Chanting',
#  'Are False',
#  'Are False',
#  'was',
#  'Chanted In',
#  'Check',
#  'Check',
#  'Revived With',
#  'Images',
#  'Check',
#  "'s",
#  'shared',
#  'Is Fake',
#  'Were Indian',
#  'Did',
#  'wants',
#  'Check',
#  'Photos Of',
#  'Photos Of',
#  'Check',
#  'Shared As',
#  'Shared As',
#  'slip over',
#  'Standing On',
#  'Shared With False',
#  'Check',
#  'go',
#  'Check',
#  'Video Of',
#  'Ask',
#  'Check',
#  'Check',
#  'Runs',
#  'Shared As',
#  'Quite',
#  'share old',
#  'Check',
#  'Photo of',
#  'Shows Pakistani',
#  'Peddled',
#  'Video of',
#  'Does',
#  'Die In',
#  'As',
#  'Video From',
#  'shared as',
#  'Chanted In',
#  'At',
#  'attacked in',
#  'Passed',
#  'shared with multiple',
#  'Check',
#  'Harassed by',
#  'shared as',
#  'Show',
#  'Say',
#  'Provide',
#  'Check',
#  'Did',
#  'Shared As',
#  'is from',
#  'Enter',
#  'Revived With',
#  'Video Of',
#  'Is',
#  'Are',
#  'Are',
#  'Did',
#  'Image of',
#  'Check',
#  'Passed',
#  'Is From',
#  'Check',
#  'wave',
#  'is from',
#  'Remove',
#  'Passed',
#  'FactCheck',
#  'made',
#  'check',
#  'is',
#  'like',
#  'is Fake',
#  'Revived',
#  'Politician',
#  'FactCheck',
#  'Revived',
#  "'s",
#  'Is',
#  'Shared As',
#  'shared as armed',
#  'Say',
#  'shared as',
#  'is',
#  'Shared',
#  'Check',
#  'Found In',
#  'Check',
#  'Revived As',
#  'Revived As',
#  'shared as',
#  'pilot',
#  'Check',
#  'is',
#  'shared',
#  'refutes',
#  'Spread',
#  'is',
#  'is',
#  'have',
#  'Check',
#  'Passed',
#  'claim',
#  'Check',
#  'fall for',
#  'Check',
#  'shared',
#  'Did',
#  'changes Indian',
#  'Check',
#  'Check',
#  'is from',
#  'Check',
#  'is',
#  'is',
#  'go',
#  'Check',
#  'share',
#  'Shared',
#  'Warn Against',
#  'doctored',
#  'Has',
#  'handing',
#  'Say',
#  'is',
#  'Is Indian',
#  'Revived After',
#  'Goes',
#  'Keeps',
#  'As',
#  'Have',
#  'Revived In',
#  'Revived',
#  'Shared As',
#  'Lathicharge',
#  'Was',
#  'Declared',
#  'Go',
#  'Is',
#  'Hold',
#  'Waved At',
#  'Wave',
#  'Waved By',
#  'Goes Viral',
#  'shared as Indian',
#  'claimed',
#  'video from',
#  'appropriate stunning',
#  'Check',
#  'claim',
#  'FactCheck',
#  'chant',
#  'chant',
#  'claim',
#  'clipped',
#  'claim',
#  'is',
#  'shout pro',
#  'raised by',
#  'is',
#  'Chanting',
#  'raise',
#  'spree',
#  'Shared As Indian',
#  'Strike',
#  'TV',
#  'Is from',
#  'Shared As',
#  'Rescued From',
#  'Check',
#  'shows',
#  'Check',
#  'Remove',
#  'video from',
#  'Is',
#  'Did',
#  'shares',
#  'shared as',
#  'Passed',
#  'tweeted fake',
#  'tweeted fake',
#  'Video',
#  'Protests',
#  "'s",
#  'Shared',
#  'is',
#  'wave',
#  'abused by',
#  'tries',
#  'edited',
#  'shared as',
#  'Is',
#  'Is',
#  'Video of',
#  'Video of',
#  'shared as',
#  'use',
#  'made',
#  'protesters',
#  'is',
#  'use',
#  'Check',
#  'Check',
#  'Video From',
#  'Check',
#  'Viral',
#  'Revived',
#  'Protesting Against',
#  'is From',
#  'meet',
#  'Check',
#  'linked',
#  'met',
#  'in',
#  'in',
#  'Peddled As',
#  'Check',
#  'Death of',
#  'Check',
#  'She',
#  'death in',
#  'Check',
#  'Check',
#  'Check of',
#  'Viral As',
#  'Check',
#  'Attack On',
#  'Video Of',
#  'Are',
#  'Passed',
#  'Goes',
#  'is',
#  'Shared As',
#  'Is',
#  'Video From',
#  'Is From',
#  'shared as',
#  'As',
#  'In',
#  'passed',
#  'video from',
#  'Give',
#  'Video From',
#  'Video',
#  'is',
#  'passed',
#  'shared as cross',
#  'Was',
#  'publishes',
#  'accounts',
#  "'s",
#  'March In',
#  'Revived After',
#  'Revived After',
#  'Revived After',
#  'Revived After',
#  'is',
#  'has',
#  'Have',
#  'Declared',
#  'is',
#  'is',
#  'waved at',
#  'check',
#  'Shared As',
#  'Check',
#  'shared in',
#  'Photos Of',
#  'Photo Of',
#  'Check',
#  'run Indore',
#  'Check',
#  'clash',
#  'Video Of',
#  'is',
#  'Say',
#  'video',
#  'photo',
#  'photo',
#  'is',
#  'Check',
#  'Keeps',
#  'Revived After',
#  'Video of irate',
#  'Declares Indian',
#  'circulated as',
#  'Say',
#  'Check',
#  'Check',
#  'As',
#  'Din',
#  'Revived',
#  'Attacks',
#  'shows old',
#  'waving',
#  'Video With',
#  'get',
#  'Check',
#  'used',
#  'falls for fake',
#  'Check',
#  'is',
#  'shared',
#  'Linked To',
#  'protest',
#  'Set',
#  'is Fake',
#  'open',
#  'Is',
#  'is',
#  'is',
#  'is',
#  'Shared As',
#  'Hotel',
#  'shows',
#  'shows',
#  'check',
#  'CHECK',
#  'is',
#  'linked to',
#  'linked to',
#  'video from',
#  'shared as',
#  'claimed',
#  'Shared',
#  'shared as',
#  'Check',
#  'Video From',
#  'Check',
#  'shared',
#  'is',
#  'Check',
#  'Passed',
#  'shared as',
#  'shared as',
#  'Video Of',
#  'Test',
#  'Shared As',
#  'has',
#  'Is',
#  'shared',
#  'Shared As',
#  'took',
#  'go viral',
#  'Is',
#  'Shared As',
#  'is',
#  'shared',
#  'Check of',
#  'Shared To',
#  'give',
#  'Video of pro',
#  'Given',
#  'Check',
#  'Check',
#  'Video of',
#  'falls for',
#  'Article On',
#  'Read',
#  'Positive',
#  'claims',
#  'claims',
#  'Check',
#  'image in',
#  'Image of',
#  'Image of',
#  'shared as Pakistani',
#  'shared as Pakistani',
#  'altered',
#  'photoshopped',
#  'Linked To',
#  'watching',
#  'photoshopped',
#  'claiming',
#  'shares old',
#  'celebration viral',
#  'made',
#  'is',
#  "'s",
#  "'s",
#  "'s",
#  "'s",
#  'shot at',
#  'Test',
#  'is',
#  'is',
#  'is',
#  'Run',
#  'shared',
#  'Check',
#  'Check',
#  'Linked To',
#  'Is',
#  'is',
#  'is',
#  'Check',
#  'viral as',
#  'Is From',
#  'is from',
#  'is from',
#  'Photo Of',
#  'Reserved',
#  'Factcheck',
#  'is',
#  'Check',
#  'Check',
#  'Check',
#  'Check',
#  'fly',
#  'Is',
#  'are',
#  'Encounter',
#  'recognised',
#  'Passed',
#  'Check',
#  'is From',
#  'was',
#  'Is Fake',
#  'Went',
#  'Check',
#  'Modi',
#  'shared as',
#  'Shared As',
#  'shared as recent',
#  'Name',
#  'claims',
#  'Starved To',
#  'Go',
#  'Article',
#  'Passed',
#  'shows',
#  'detaining',
#  'Passed',
#  'Passed',
#  'passed',
#  'Video Of',
#  'Passed',
#  'Shared As',
#  'Shared As',
#  'Shared As',
#  'is',
#  'Shared As',
#  'Shared As',
#  'Shared As',
#  'Is',
#  'As',
#  'Using',
#  'Supports',
#  'fabricate',
#  'Passed',
#  'Banned In',
#  'claim',
#  'Shared As',
#  'FactCheck',
#  'Check',
#  'Check',
#  'FactCheck',
#  'Shared As',
#  'Shared As',
#  'shared as',
#  'Passed',
#  'Check',
#  'burn',
#  'Revived',
#  'Viral As',
#  'fall for',
#  'Passed',
#  'Revived',
#  'Added To',
#  'claim',
#  'Is',
#  'is',
#  'Name',
#  'Image From',
#  'Shared As',
#  'is',
#  'Check',
#  'Video Of',
#  'is from',
#  'shared as',
#  'shared with false',
#  'Protests',
#  'is Dead',
#  'is Dead',
#  'is Dead',
#  'Die In',
#  'is Indian',
#  'Check',
#  'Photos Of',
#  'Check',
#  'is',
#  'Read',
#  'shared as',
#  'shared as Pakistani',
#  'went lower',
#  'Check',
#  'are from',
#  'News Of',
#  'Video of',
#  'Video Of',
#  'recirculates',
#  'kissing',
#  'Shared As',
#  'Did',
#  'shared as',
#  'lose',
#  'Staged',
#  'News',
#  'is',
#  'Go',
#  'impersonates',
#  'Shared',
#  'shared as',
#  'shared as',
#  'shared amidst recent',
#  'Shared as',
#  'Has',
#  'Check',
#  'is',
#  'video from',
#  'drop',
#  'says',
#  'risks',
#  'takes social',
#  'arrests',
#  'Matters',
#  'Again in',
#  'restrictions',
#  'seals',
#  'Pakistan as',
#  'responds',
#  'says',
#  'enters into',
#  'says',
#  'partners with key',
#  'resume',
#  'provide',
#  'Author of new',
#  'treaty',
#  'set',
#  'Say',
#  'Persecution of',
#  'dominate',
#  'poses',
#  "'s",
#  'dies',
#  'Enters Into',
#  'Says',
#  'Kohli',
#  'Goes',
#  'Healing',
#  'is',
#  'prospects unchanged',
#  'Cricket',
#  'Lankans',
#  'request',
#  'Missile vs.',
#  'Hide Behind',
#  'UN',
#  'UN',
#  'goes to',
#  'approves global',
#  'film',
#  'Cullinan on',
#  'recall',
#  'Navy',
#  'slams',
#  'slams',
#  'request by',
#  'prospects unchanged',
#  'Spokesperson',
#  'women out',
#  'request',
#  'takes',
#  'Open',
#  'approves global',
#  'with',
#  'treaty',
#  'treaty',
#  'Destroy',
#  'releases',
#  'Quiz',
#  'Manager For',
#  'drop',
#  'On',
#  'reaping',
#  'feels',
#  'SBP',
#  'organises',
#  'Beat',
#  'Awe',
#  'says',
#  'Highway to',
#  'Poses',
#  'Deafening',
#  'KBC',
#  'Banning',
#  'treaty',
#  'dominate',
#  'Expanding multilateral',
#  'made',
#  'treaty',
#  'ran for',
#  'drives',
#  'violates',
#  'blast',
#  'Medicine',
#  'Johnson',
#  'terror',
#  'return to',
#  'treaty',
#  'says ironic',
#  'need',
#  'ने',
#  'approves global',
#  'Breathe Harmful',
#  'Nigeria',
#  'Powder',
#  'decrease by',
#  'killed in',
#  'tells',
#  'tests medium',
#  'changed',
#  'Hot',
#  'Starts',
#  'plans',
#  'gift',
#  'faces',
#  'In',
#  'Produce',
#  'gift',
#  'gets',
#  'overcame',
#  'Announces Successful',
#  'Missile',
#  'offer',
#  'Says',
#  'Surge',
#  'Estimates',
#  'Plessis',
#  'killed',
#  'killed',
#  'seeks',
#  'announces',
#  'offers',
#  'Role As',
#  'Mobile',
#  'list',
#  'film for stable',
#  'Are',
#  'confirm',
#  'joins',
#  'Relief from',
#  'compounds with aromatic',
#  'Role as',
#  'seeks',
#  'Promises High',
#  'Khan',
#  'return to',
#  'Version Of',
#  'Killed In',
#  'is',
#  'Plessis',
#  'Cooperation',
#  'Primer to',
#  'Search for',
#  'reach',
#  'lauds',
#  'hit',
#  'strain',
#  'Indulge in',
#  'Covax',
#  'China to',
#  'Are',
#  'pushes',
#  'Number of',
#  'dies',
#  'killed in',
#  'Says',
#  'Brazil among',
#  'congratulates',
#  'reveal',
#  'led',
#  'Hafeez',
#  'dies',
#  'seeks',
#  'Make',
#  'gift',
#  'Day',
#  'Stokes',
#  'named',
#  'is',
#  'News24.com',
#  'Spotted',
#  'convinced',
#  'Hope For',
#  'make',
#  'is',
#  'hands',
#  'In 1st',
#  'Diplomacy In',
#  'shines',
#  'Hold',
#  'Goes After',
#  'is',
#  'redefining',
#  'Phangiso',
#  'goes official',
#  'Stokes',
#  'Call for',
#  'tells',
#  'Correction',
#  'Do',
#  'Reuters',
#  'Threaten',
#  'begins',
#  'Meet',
#  'overcame',
#  'appoints former',
#  'play for',
#  'made K2',
#  'Remember',
#  'Becomes',
#  'pride',
#  'say',
#  'Set',
#  'Genes',
#  'Updates',
#  'sets',
#  'aflame',
#  'leads',
#  'Convert Into',
#  'dies',
#  'leave many',
#  'hit',
#  'projected',
#  'leave many',
#  'upends',
#  'Market',
#  'signals',
#  'remove',
#  'project',
#  'says',
#  'celebrate',
#  'says',
#  'Modi',
#  'drop',
#  'export',
#  'Hope',
#  'opens for',
#  'Announces Successful',
#  'Have',
#  'dies',
#  'Rwanda',
#  'leave many',
#  'Identifying intentional',
#  'Characteristics',
#  'algorithm',
#  'Infiltrators From',
#  'spotted',
#  'praise',
#  'is',
#  'is',
#  'Weapons',
#  'Everything',
#  'Capitalize on',
#  'Nukes',
#  'get',
#  'is',
#  'Predictions',
#  'breathe harmful',
#  'bruised',
#  'Is',
#  'dies from',
#  'Research for',
#  'says',
#  'Pakistan in',
#  'Protest In',
#  'belt',
#  'says',
#  'raped',
#  'Are',
#  'alert',
#  'Flown',
#  'nod for',
#  'lays',
#  'works on',
#  'Officials',
#  'Day',
#  'Exam',
#  'L',
#  'Hails',
#  'Said On',
#  'Deserve More',
#  'check on',
#  'says',
#  'leave many',
#  'starts',
#  'killed',
#  'says',
#  'stresses on',
#  'alert',
#  'dies in',
#  'sues British',
#  'starts',
#  'upends',
#  'demonstrate homegrown',
#  'provide',
#  'Continues to',
#  '|',
#  'govt',
#  'hails',
#  'Celebrate',
#  'injured',
#  'alleges',
#  'says',
#  'Officials',
#  'Austin',
#  'Accomplices in',
#  'K2 in',
#  'approves',
#  'Inauguration',
#  'found near K2',
#  'found dead',
#  'gives',
#  'protest against',
#  'approves',
#  'Khan',
#  'lands',
#  'found dead',
#  'student for',
#  'Tracing',
#  'sees red',
#  'gave',
#  'explores',
#  'approves',
#  'found near',
#  'approves',
#  'gave',
#  'Blasts',
#  'cites global',
#  'bet on crypto',
#  'judge',
#  'Providing official',
#  'CAA',
#  'PCB',
#  'Joshi',
#  'finds',
#  'Found Dead',
#  'Cities With',
#  'captain new',
#  'begins',
#  'Fundraiser',
#  'try',
#  'Hit By',
#  'Courting',
#  'mulls',
#  'begins massive',
#  'Vows',
#  'rescued in',
#  'Shows',
#  'raise',
#  'India',
#  'blazes half',
#  'funds',
#  'get',
#  'Is',
#  'criticises',
#  'is likely',
#  'grow with',
#  'likely',
#  'Hundred',
#  'Secures',
#  'send',
#  'rescued',
#  'be among',
#  'Syed',
#  'Book',
#  'Investigate',
#  'approves',
#  'approves',
#  'going',
#  'From',
#  'delivers',
#  'be',
#  'News',
#  'Pakistan',
#  'gates',
#  'thief',
#  'Coronavirus',
#  'found dead',
#  'angry over',
#  'women',
#  'means for',
#  'suspends',
#  'awarded',
#  'Change of',
#  'use',
#  'Fence',
#  'Klaasen',
#  'Explained',
#  'Drinks For',
#  'Thank',
#  'opens for',
#  'MPA’21',
#  'Reclaim',
#  'Know',
#  'efficacy of different',
#  'predictors of',
#  'draws',
#  'Waziristan',
#  'declares',
#  'discloses',
#  'Raring',
#  'angry over',
#  'Cafe After',
#  'Appears',
#  'approves',
#  'Rise in',
#  'leads',
#  'found dead',
#  'Sacrificing',
#  'target',
#  'J&K',
#  'Revealed',
#  'herder from',
#  'imams',
#  'is',
#  'Defies',
#  'Transformative',
#  'release',
#  'imams',
#  'recounts',
#  'rises with',
#  'likely',
#  'Transformative',
#  'Bahrani',
#  'clothes',
#  'condemns',
#  'Day',
#  'relationship with',
#  'Raises',
#  'reveals',
#  'drop',
#  'is Better',
#  "'",
#  'ripped',
#  'question of',
#  ...]

# %%
import  csv

with open("PakistaniDatasetRelations.csv","w") as f:
    wr = csv.writer(f,delimiter="\n")
    wr.writerow(relations3)
